# %%
df = pd.read_csv('high.csv')

# %%
df
# Out:
#                                        Glaze name     Cone  \
# 0                                    Blue lithium   010-09
# 1                                    Yellow Lewis       10
# 2                                  Blue Limestone       10
# 3                                     Purple Chun       10
# 4        Matt Strontium Crystal Magic Steven Hill       10
# 5                                          #207.3        8
# 6                                    Albany Glaze   9 - 10
# 7                Albany Slip substitute Hendley's   7 - 10
# 8                            Alkaline High Fire 1     9-10
# 9                            Alkaline high fire 2       10
# 10                     Alkaline high fire 2 no cs       10
# 11                           Alkaline Lee Rexrode        9
# 12                        Alkaline Lee Rexrode Sr        9
# 13                                  Amber Barnard       10
# 14                                  Amber Celadon   9 - 10
# 15                   Amber Celadon McKenzie Smith     9-10
# 16                     Amber Celadon Nick's Ochre       10
# 17                       Amber Celadon no  Albany   9 - 10
# 18                        Amber Celadon no albany   9 - 10
# 19                     Amber Celadon VC no albany       10
# 20                   Amber Celadon w/Alberta Slip       10
# 21                                 Amber Gulden's       10
# 22                           Amber Gulden's no GB       10
# 23                      Amber Shaner Celadon ARAC     9-10
# 24              Amber Shaner Celadon ARAC Alberta     9-10
# 25            Amber Shaner Celadon ARAC no albany     9-10
# 26                            Amber stable test 1       10
# 27                 Amber stable test 2 w/bone ash       10
# 28                            Amber theoretical 3       10
# 29                                  Anderson Blue   9 - 10
# ..                                            ...      ...
# 721                                      White PV   8 - 10
# 722                      White Satin Matt Orielly   9 - 10
# 723                  White Satin Matte Margaret's        9
# 724  White Satin Matte Margaret's Glaze calc prob        9
# 725                               White Semi-Matt       10
# 726                                   White Shiny     9-10
# 727                                  White Sperry       10
# 728                                White Sycamore   9 - 10
# 729                                  White Temple       10
# 730                               White V.C. Matt   9 - 10
# 731                                    White Waxy   6 - 10
# 732                               White Waxy Matt       10
# 733                                White Yanigara  10 - 11
# 734                                      Woo Base   9 - 10
# 735                                  Yellow Amber       10
# 736                           YELLOW Amber Martin       10
# 737                                    YELLOW AME       10
# 738                                   Yellow Ferg       10
# 739                                   Yellow Ferg       10
# 740                      Yellow GWashington Lewis       10
# 741                                 Yellow Korman   9 - 10
# 742                                  Yellow Lewis       10
# 743                           Yellow Lewis RR rev       10
# 744                              Yellow Matt Flow     9-10
# 745                             Yellow Salt Horie       10
# 746                             Yellow School Bus       10
# 747                                Yellow Winokur       10
# 748                                    Yellow Woo   9 - 10
# 749                                 Yellow Woo #2   9 - 10
# 750                                         Zello       10
#
#                      Color   Testing              Surface       Firing  \
# 0                     Blue       NaN           Semi-gloss  Ox. or Red.
# 1                      NaN       NaN           Satin matt    Reduction
# 2                      NaN       NaN           Semi-gloss    Reduction
# 3               Red-purple       NaN                Gloss    Reduction
# 4                    White       NaN           Satin matt    Reduction
# 5    varies - see comments       NaN                Gloss    Oxidation
# 6                      NaN       NaN                  NaN          NaN
# 7              brown black       NaN               glossy  ox. or red.
# 8                    Clear       NaN                Gloss  Ox. or Red.
# 9                      NaN       NaN                Gloss  Ox. or Red.
# 10                     NaN       NaN                Gloss  Ox. or Red.
# 11                   White       NaN           Satin matt    Oxidation
# 12                   White       NaN           Satin matt    Oxidation
# 13                   Amber       NaN                Gloss    Reduction
# 14     Amber, honey, brown  Untested               Glossy    Reduction
# 15                   Amber       NaN                Gloss    Reduction
# 16                   Amber       NaN                Gloss    Reduction
# 17     Amber, honey, brown  Untested               Glossy    Reduction
# 18     Amber, honey, brown  Untested               Glossy    Reduction
# 19                   Amber       NaN                Gloss    Reduction
# 20                     NaN       NaN                Gloss    Reduction
# 21                   Amber       NaN                Gloss    Reduction
# 22                   Amber       NaN                Gloss    Reduction
# 23                   Amber       NaN                Gloss    Reduction
# 24                   Amber       NaN                Gloss    Reduction
# 25                   Brown    Tested                Gloss    Reduction
# 26                   Amber       NaN                Gloss    Reduction
# 27                   Amber       NaN                Gloss    Reduction
# 28                   Amber  Untested                Gloss    Reduction
# 29    black to green, blue       NaN                matte    reduction
# ..                     ...       ...                  ...          ...
# 721                  White       NaN         shiny glossy          NaN
# 722                  White       NaN                Satin  Ox. or Red.
# 723                  White       NaN           Satin matt    Oxidation
# 724                  White       NaN           Satin matt    Oxidation
# 725                  white       NaN            semi-matt    Reduction
# 726                  White       NaN                Gloss    Reduction
# 727                  White       NaN                Gloss    Reduction
# 728                  white       NaN                Gloss  Ox. or Red.
# 729                  white       NaN                 Waxy          NaN
# 730                  White  Untested          Satin Matte    Ox or Red
# 731                  White  Untested  fat waxy satin matt  Ox. or Red.
# 732                  white  Untested                 Waxy  Ox. or Red.
# 733                  White       NaN           Satin matt    Reduction
# 734          Yellow Opaque  Untested          Stoney Matt    Reduction
# 735                  Amber       NaN                Gloss  Salt - Soda
# 736      iron yellow brown       NaN                  NaN          NaN
# 737      iron yellow brown       NaN                  NaN          NaN
# 738                    NaN       NaN           Satin matt    Reduction
# 739                 Yellow       NaN           Satin matt    Reduction
# 740                 yellow       NaN                matte    reduction
# 741                 Yellow  Untested                 Matt    Reduction
# 742                 yellow       NaN                matte    reduction
# 743                 yellow       NaN                matte    reduction
# 744                 Yellow       NaN                 Matt    Reduction
# 745                 Yellow       NaN                Gloss  Salt - Soda
# 746                 Yellow       NaN                Gloss  Ox. or Red.
# 747                    NaN  Untested                 matt    reduction
# 748          Yellow Opaque  Untested          Stoney Matt    Reduction
# 749                 yellow       NaN                matte          NaN
# 750                 Yellow       NaN                Gloss  Salt - Soda
#
#     Transparency                        Recipe1                     Recipe2  \
# 0         Opaque                   Flint\t40.40            Soda spar\t20.20
# 1            NaN                Feldspar\t35.00            Ball clay\t22.00
# 2            NaN                   Kaolin\t9.50              Whiting\t19.00
# 3         Opaque         Custer feldspar\t26.00                Flint\t29.50
# 4         Opaque         Custer feldspar\t46.00              Whiting\t17.30
# 5            NaN       Nepheline syenite\t35.00             Dolomite\t15.00
# 6            NaN             Albany slip\t63.16       Cornwall Stone\t26.32
# 7            NaN                  Redart\t72.00              Whiting\t10.00
# 8    Transparent                Feldspar\t62.50               Whiting\t7.70
# 9    Transparent                Feldspar\t20.00       Cornwall Stone\t50.00
# 10   Transparent                Feldspar\t51.71              Whiting\t16.27
# 11   Semi-opaque        Barium carbonate\t36.60     Lithium carbonate\t1.10
# 12   Translucent     Strontium carbonate\t27.50     Lithium carbonate\t1.10
# 13   Transparent            Barnard clay\t33.00         Wollastonite\t13.00
# 14           NaN             Albany Slip\t36.00      Custer feldspar\t22.00
# 15   Transparent                Wood ash\t22.00              Whiting\t17.00
# 16   Transparent         Custer feldspar\t26.50              Whiting\t22.20
# 17           NaN    Kaolin - theoretical\t15.00      Custer feldspar\t28.00
# 18           NaN    Kaolin - theoretical\t12.00      Custer feldspar\t29.00
# 19   Translucent         Custer feldspar\t19.00       Gerstley borate\t3.00
# 20   Transparent            Alberta slip\t35.50         Wollastonite\t14.00
# 21   Translucent         Custer feldspar\t30.00              Whiting\t25.00
# 22   Translucent  feldspar - theoretical\t25.60              Whiting\t26.60
# 23   Transparent             Albany slip\t35.90         Wollastonite\t14.10
# 24   Transparent            Alberta slip\t77.00       Gerstley borate\t3.00
# 25   Transparent                     EPK\t14.00              Dolomite\t5.00
# 26   Transparent                Feldspar\t47.90              Whiting\t14.70
# 27   Transparent                Feldspar\t47.70  Strontium carbonate\t11.00
# 28   Transparent       Nepheline syenite\t34.10     Lithium carbonate\t2.00
# 29           NaN           Soda feldspar\t57.13                  EPK\t14.26
# ..           ...                            ...                         ...
# 721       Opaque          Plastic vitrox\t50.00           Colemanite\t50.00
# 722       Opaque         Custer feldspar\t56.00      Barium carbonate\t2.00
# 723  Semi-opaque         Custer feldspar\t43.00      Gerstley borate\t12.00
# 724  Semi-opaque       Nepheline syenite\t20.30                 Talc\t19.10
# 725  Semi-opaque          Cornwall Stone\t84.21              Whiting\t15.79
# 726  Semi-opaque       Kona F-4 feldspar\t56.00                Flint\t21.00
# 727       Opaque         Custer feldspar\t71.43       Kentucky OM #4\t14.29
# 728       Opaque                 Whiting\t18.20      Custer feldspar\t50.20
# 729       Opaque         Potash feldspar\t34.31             Dolomite\t19.31
# 730  Translucent           Kona F-4 spar\t25.00          Custer spar\t20.00
# 731       Opaque        Kingman feldspar\t41.00               Silica\t20.00
# 732  Semi-opaque         Custer feldspar\t46.59      Gerstley borate\t15.91
# 733       Opaque          G-200 feldspar\t39.70                 Talc\t12.90
# 734          NaN           Kona F-4 Spar\t34.00     Barium carbonate\t25.00
# 735       Opaque         Custer feldspar\t29.00              Whiting\t20.50
# 736          NaN         Custer feldspar\t33.00             Dolomite\t11.00
# 737          NaN         Custer feldspar\t33.00             Dolomite\t11.00
# 738          NaN         Potash feldspar\t46.30             Dolomite\t15.00
# 739       Opaque         Potash feldspar\t46.30             Dolomite\t15.00
# 740       Opaque            F-4 feldspar\t43.36  Strontium carbonate\t18.44
# 741       Opaque           Kona F-4 spar\t40.00     Barium carbonate\t30.00
# 742          NaN            F-4 feldspar\t33.86  Strontium carbonate\t18.38
# 743          NaN            F-4 feldspar\t34.00  Strontium carbonate\t18.50
# 744       Opaque          Cornwall Stone\t53.00                Flint\t14.00
# 745       Opaque       Nepheline syenite\t63.90             Dolomite\t21.10
# 746       Opaque           NC-4 feldspar\t18.00      Custer feldspar\t21.00
# 747          NaN         Potash feldspar\t53.23             Dolomite\t19.39
# 748          NaN           Kona F-4 spar\t34.00     Barium carbonate\t25.00
# 749          NaN         Custer feldspar\t42.78     Barium carbonate\t32.49
# 750  Transparent       Nepheline syenite\t20.00    Lithium carbonate\t10.00
#
#                         Recipe3                      Recipe4  \
# 0               Cryolite\t15.20     Lithium carbonate\t10.10
# 1                   Flint\t5.00      Barium carbonate\t25.28
# 2                 Silica\t28.60              Feldspar\t38.10
# 3                Whiting\t15.10                    EPK\t1.80
# 4            Tile 6 clay\t14.90   Strontium carbonate\t12.60
# 5                 Whiting\t8.00       Barium carbonate\t8.00
# 6                Whiting\t10.53         Red iron oxide\t5.26
# 7           Soda feldspar\t8.00                   Talc\t5.00
# 8                     EPK\t5.10                 Flint\t24.60
# 9                Whiting\t15.00                 Flint\t15.00
# 10               Dolomite\t0.32                Silica\t26.89
# 11     Nepheline syenite\t45.60              Ball clay\t7.20
# 12     Nepheline syenite\t45.60              Ball clay\t7.20
# 13               Whiting\t15.00       Custer feldspar\t20.00
# 14        Gerstley borate\t3.00          Wollastonite\t14.00
# 15       Custer feldspar\t41.00              Ball clay\t4.00
# 16                 Flint\t25.60             Ball clay\t25.60
# 17               Dolomite\t4.00               Whiting\t19.00
# 18               Dolomite\t4.00               Whiting\t20.00
# 19               Dolomite\t2.00           Wollastonite\t9.00
# 20        K-200 feldspar\t21.50        Gerstley borate\t3.20
# 21                 Flint\t25.00        Kentucky OM #4\t10.00
# 22                Silica\t30.90   Kaolin - theoretical\t7.70
# 23                    EPK\t3.30        Gerstley borate\t3.30
# 24               Whiting\t14.00                 Silica\t6.00
# 25               Whiting\t19.00                Silica\t29.00
# 26   Strontium carbonate\t11.00   Kaolin - theoretical\t9.80
# 27   Kaolin - theoretical\t9.80                Silica\t16.50
# 28               Whiting\t12.10    Strontium carbonate\t5.90
# 29         Kentucky OM #4\t7.18               Whiting\t21.44
# ..                          ...                          ...
# 721             Zircopax\t15.00                          NaN
# 722              Dolomite\t8.00               Whiting\t10.00
# 723              Dolomite\t7.00                  Talc\t14.00
# 724          Wollastonite\t2.60  Kaolin - theoretical\t12.20
# 725             Tin oxide\t5.26                          NaN
# 726              Whiting\t15.00         Kentucky OM #4\t8.00
# 727                  Talc\t9.52             Colemanite\t4.76
# 728                  EPK\t12.60                 Flint\t19.10
# 729               Whiting\t2.55                   EPK\t22.25
# 730               Whiting\t9.00              Dolomite\t10.00
# 731                 Talc\t15.00       Gerstley borate\t12.00
# 732              Dolomite\t7.95                 Kaolin\t5.68
# 733              Whiting\t16.80                Silica\t27.70
# 734             Dolomite\t12.00                    EPK\t7.00
# 735                  EPK\t19.00                 Flint\t31.50
# 736              Whiting\t17.00             Zinc oxide\t6.00
# 737              Whiting\t17.00             Zinc oxide\t6.00
# 738               Whiting\t9.20               Bone ash\t7.40
# 739               Whiting\t9.20               Bone ash\t7.40
# 740             Dolomite\t11.56    Talc (milled white)\t1.22
# 741                   EPK\t8.00                 Flint\t10.00
# 742             Dolomite\t11.75              Ball clay\t6.98
# 743             Dolomite\t12.00        Kentucky OM #4\t13.00
# 744                   EPK\t8.00               Whiting\t26.00
# 745        Kentucky OM #4\t4.30              Superpax\t16.00
# 746              Dolomite\t6.00                Whiting\t9.00
# 747                  EPK\t22.91                Whiting\t4.48
# 748             Dolomite\t12.00                    EPK\t7.00
# 749             Dolomite\t15.32                    EPK\t9.41
# 750              Whiting\t17.10                   EPK\t10.00
#
#                         Recipe5                  Recipe6  \
# 0                Bone ash\t8.10             Kaolin\t3.00
# 1                   Opax\t15.00     Red iron oxide\t6.00
# 2        Barium carbonate\t4.80             Rutile\t4.80
# 3               Ball clay\t5.60           Soda ash\t7.10
# 4               Frit 3124\t4.60  Lithium carbonate\t4.60
# 5                     EPK\t4.00            Silica\t30.00
# 6                           NaN                      NaN
# 7              EPK kaolin\t5.00                      NaN
# 8                           NaN                      NaN
# 9                           NaN                      NaN
# 10   Kaolin - theoretical\t6.71                      NaN
# 11                  Flint\t9.50                      NaN
# 12                  Flint\t9.50                      NaN
# 13        Gerstley borate\t3.00                      NaN
# 14                Whiting\t8.00             Flint\t14.00
# 15                 Flint\t17.00     Red iron oxide\t8.00
# 16           Yellow ochre\t8.00                      NaN
# 17                Silica\t30.00          Frit 3134\t3.00
# 18                Silica\t30.00          Frit 3195\t5.00
# 19               Whiting\t14.00            Redart\t29.00
# 20                Whiting\t7.50                EPK\t3.20
# 21        Gerstley borate\t3.00          Bentonite\t2.00
# 22              Frit 3124\t9.20          Bentonite\t2.00
# 23                Whiting\t7.60             Flint\t14.10
# 24           Yellow ochre\t8.00                      NaN
# 25       Custer feldspar\t27.00          Frit 3134\t6.00
# 26                Silica\t16.60     Red iron oxide\t8.00
# 27              Bone ash\t15.10     Red iron oxide\t8.00
# 28   Kaolin - theoretical\t1.20            Silica\t44.60
# 29       Cobalt carbonate\t7.18                      NaN
# ..                          ...                      ...
# 721                         NaN                      NaN
# 722                   EPK\t6.00         Zinc oxide\t4.00
# 723                Kaolin\t5.00             Flint\t19.00
# 724               Silica\t22.90         Frit 3134\t20.20
# 725                         NaN                      NaN
# 726             Tin oxide\t1.10          Bentonite\t2.20
# 727                         NaN                      NaN
# 728             Zircopax\t25.50                      NaN
# 729                Flint\t19.61          Bentonite\t1.96
# 730                  Talc\t6.00                EPK\t4.00
# 731              Dolomite\t7.00                EPK\t5.00
# 732                Flint\t23.86             Ultrox\t6.82
# 733                   EPK\t3.00          Bentonite\t2.00
# 734                 Flint\t7.00          Zircopax\t15.00
# 735                Rutile\t7.00                      NaN
# 736                  EPK\t11.00            Silica\t22.00
# 737                  EPK\t11.00            Silica\t22.00
# 738               Kaolin\t22.20           Zircopax\t7.40
# 739               Kaolin\t22.20           Zircopax\t7.40
# 740       Kentucky OM #4\t11.22            Silica\t14.20
# 741             Dolomite\t12.00     Red iron oxide\t6.00
# 742       Plastic vitrox\t24.18             Silica\t4.84
# 743            G-200 spar\t9.50            Silica\t13.00
# 744        Red iron oxide\t3.00            Rutile\t10.00
# 745             Bentonite\t4.00     Red iron oxide\t1.00
# 746  Strontium carbonate\t12.00         Ball clay\t10.00
# 747             Zircopax\t16.92          Tin oxide\t3.49
# 748                 Flint\t7.00          Zircopax\t15.00
# 749             Tin oxide\t9.41     Red iron oxide\t3.28
# 750            Frit P-25\t42.90           Zircopax\t5.70
#
#                      Recipe7                 Recipe8          Recipe9  \
# 0         Copper oxide\t3.00                     NaN              NaN
# 1                        NaN                     NaN              NaN
# 2     Copper carbonate\t1.60  Cobalt carbonate\t1.90  Bentonite\t2.00
# 3           Frit 3134\t11.30  Barium carbonate\t4.00  Tin oxide\t1.10
# 4    Titanium dioxide\t13.80         Bentonite\t2.00              NaN
# 5            Bentonite\t3.00                     NaN              NaN
# 6                        NaN                     NaN              NaN
# 7                        NaN                     NaN              NaN
# 8                        NaN                     NaN              NaN
# 9                        NaN                     NaN              NaN
# 10                       NaN                     NaN              NaN
# 11                       NaN                     NaN              NaN
# 12                       NaN                     NaN              NaN
# 13                       NaN                     NaN              NaN
# 14                 EPK\t3.00      Yellow Ochre\t9.00              NaN
# 15           Bentonite\t2.00                     NaN              NaN
# 16                       NaN                     NaN              NaN
# 17      Red iron oxide\t3.00                     NaN              NaN
# 18      Red iron oxide\t3.00                     NaN              NaN
# 19       Barnard clay\t10.00               EPK\t2.00     Flint\t10.00
# 20             Silica\t15.10      Yellow ochre\t7.50  Bentonite\t6.50
# 21   Yellow iron oxide\t7.00                     NaN              NaN
# 22   Yellow iron oxide\t7.00                     NaN              NaN
# 23    Custer feldspar\t21.70      Yellow ochre\t8.70              NaN
# 24                       NaN                     NaN              NaN
# 25        Yellow ochre\t8.00                     NaN              NaN
# 26           Bentonite\t2.00                     NaN              NaN
# 27           Bentonite\t2.00                     NaN              NaN
# 28      Red iron oxide\t8.00         Bentonite\t2.00              NaN
# 29                       NaN                     NaN              NaN
# ..                       ...                     ...              ...
# 721                      NaN                     NaN              NaN
# 722           Petalite\t3.00            Flint\t11.00   Zircopax\t6.00
# 723                      NaN                     NaN              NaN
# 724                      NaN                     NaN              NaN
# 725                      NaN                     NaN              NaN
# 726           Zircopax\t8.79                     NaN              NaN
# 727                      NaN                     NaN              NaN
# 728                      NaN                     NaN              NaN
# 729                      NaN                     NaN              NaN
# 730   Calcined kaolin\t14.00            Flint\t12.00  Bentonite\t2.00
# 731                      NaN                     NaN              NaN
# 732                      NaN                     NaN              NaN
# 733                      NaN                     NaN              NaN
# 734                      NaN                     NaN              NaN
# 735                      NaN                     NaN              NaN
# 736             Rutile\t5.00    Red iron oxide\t2.00              NaN
# 737             Rutile\t5.00    Red iron oxide\t2.00              NaN
# 738     Red iron oxide\t1.10            Rutile\t1.10              NaN
# 739     Red iron oxide\t1.10            Rutile\t1.10              NaN
# 740     Red iron oxide\t2.84                     NaN              NaN
# 741                      NaN                     NaN              NaN
# 742     Red iron oxide\t2.90                     NaN              NaN
# 743     Red iron oxide\t3.00                     NaN              NaN
# 744                      NaN                     NaN              NaN
# 745                      NaN                     NaN              NaN
# 746             Flint\t16.00          Zircopax\t8.00              NaN
# 747     Red iron oxide\t1.30                     NaN              NaN
# 748     Red iron oxide\t3.00                     NaN              NaN
# 749                      NaN                     NaN              NaN
# 750                      NaN                     NaN              NaN
#
#                    Recipe10 Recipe11 Recipe12  Recipe13
# 0                       NaN      NaN      NaN       NaN
# 1                       NaN      NaN      NaN       NaN
# 2                       NaN      NaN      NaN       NaN
# 3    Copper carbonate\t0.50      NaN      NaN       NaN
# 4                       NaN      NaN      NaN       NaN
# 5                       NaN      NaN      NaN       NaN
# 6                       NaN      NaN      NaN       NaN
# 7                       NaN      NaN      NaN       NaN
# 8                       NaN      NaN      NaN       NaN
# 9                       NaN      NaN      NaN       NaN
# 10                      NaN      NaN      NaN       NaN
# 11                      NaN      NaN      NaN       NaN
# 12                      NaN      NaN      NaN       NaN
# 13                      NaN      NaN      NaN       NaN
# 14                      NaN      NaN      NaN       NaN
# 15                      NaN      NaN      NaN       NaN
# 16                      NaN      NaN      NaN       NaN
# 17                      NaN      NaN      NaN       NaN
# 18                      NaN      NaN      NaN       NaN
# 19     Red iron oxide\t2.00      NaN      NaN       NaN
# 20                      NaN      NaN      NaN       NaN
# 21                      NaN      NaN      NaN       NaN
# 22                      NaN      NaN      NaN       NaN
# 23                      NaN      NaN      NaN       NaN
# 24                      NaN      NaN      NaN       NaN
# 25                      NaN      NaN      NaN       NaN
# 26                      NaN      NaN      NaN       NaN
# 27                      NaN      NaN      NaN       NaN
# 28                      NaN      NaN      NaN       NaN
# 29                      NaN      NaN      NaN       NaN
# ..                      ...      ...      ...       ...
# 721                     NaN      NaN      NaN       NaN
# 722                     NaN      NaN      NaN       NaN
# 723                     NaN      NaN      NaN       NaN
# 724                     NaN      NaN      NaN       NaN
# 725                     NaN      NaN      NaN       NaN
# 726                     NaN      NaN      NaN       NaN
# 727                     NaN      NaN      NaN       NaN
# 728                     NaN      NaN      NaN       NaN
# 729                     NaN      NaN      NaN       NaN
# 730                     NaN      NaN      NaN       NaN
# 731                     NaN      NaN      NaN       NaN
# 732                     NaN      NaN      NaN       NaN
# 733                     NaN      NaN      NaN       NaN
# 734                     NaN      NaN      NaN       NaN
# 735                     NaN      NaN      NaN       NaN
# 736                     NaN      NaN      NaN       NaN
# 737                     NaN      NaN      NaN       NaN
# 738                     NaN      NaN      NaN       NaN
# 739                     NaN      NaN      NaN       NaN
# 740                     NaN      NaN      NaN       NaN
# 741                     NaN      NaN      NaN       NaN
# 742                     NaN      NaN      NaN       NaN
# 743                     NaN      NaN      NaN       NaN
# 744                     NaN      NaN      NaN       NaN
# 745                     NaN      NaN      NaN       NaN
# 746                     NaN      NaN      NaN       NaN
# 747                     NaN      NaN      NaN       NaN
# 748                     NaN      NaN      NaN       NaN
# 749                     NaN      NaN      NaN       NaN
# 750                     NaN      NaN      NaN       NaN
#
# [751 rows x 20 columns]

# %%
df.Recipe12.value_counts()
# Out:
# Bentonite\t3.10           1
# Copper carbonate\t2.30    1
# Bentonite\t3.12           1
# Name: Recipe12, dtype: int64

# %%
df.Recipe13.value_counts()
# Out:
# Series([], Name: Recipe13, dtype: int64)

# %% [markdown]
# # Glaze name

# %%
df['Glaze name'] = df['Glaze name'].str.lower()
df['Glaze name'].value_counts()
# Out:
# tomato red                                     5
# satin rick haynes                              2
# clay casting porcelain slip michael corney     2
# gray-white translucent                         2
# slip black                                     2
# black sloan's                                  2
# crystalline glaze hewitt                       2
# black hendley's rhodes                         2
# clear matt hewitt's                            2
# shino southwest craft center                   2
# yellow lewis                                   2
# yellow ferg                                    2
# shino bill buckner's carbon trapping orange    2
# ash fake bp26s light green                     2
# slip #1818 kawai                               2
# white cornwall                                 2
# rivulet v.c.                                   2
# base ayumi's tuesday                           2
# clear buttery matt #415                        2
# tesha boubaric                                 2
# slip uf high-fire tizzy                        1
# slip bringle                                   1
# v.c. ir-d                                      1
# bronze gold metallic                           1
# crystalline aaonsen & johnson                  1
# slip uf shop black                             1
# clay stoneware white vc                        1
# copper red peach blossom                       1
# v.c. black satin matt                          1
# base 8a                                        1
#                                               ..
# rivulet v.c. #1                                1
# shino tight crawl no rhyolite                  1
# clear                                          1
# white pete's charlie ian anderson              1
# shino glaze                                    1
# clay casting anna's                            1
# blue periwinkle kelli's                        1
# shino #4                                       1
# amber barnard                                  1
# blue dark gloss                                1
# blacksmith                                     1
# persimmon                                      1
# ash green cooter                               1
# red shaner                                     1
# blue v.c. rich matt                            1
# black st john's                                1
# turquoise                                      1
# base val's aa horie                            1
# strawberry crush george's                      1
# tenmoku yuteki (oilspot)                       1
# rene' ben lisa (france)                        1
# clay stoneware rick st. john's                 1
# ash pale green                                 1
# clay stoneware high-iron ted adler's           1
# black breaking blue                            1
# celadon 1234                                   1
# black sloan's  revisited                       1
# lab fee intense red                            1
# green willie hillix                            1
# celadon grey                                   1
# Name: Glaze name, Length: 728, dtype: int64

# %% [markdown]
# # Cone

# %%
df['Cone'] = df['Cone'].str.lower()
df['Cone'].replace(['10 - 12', '10-12'], '11', inplace=True)
df['Cone'].replace(['10 - 11', '10-11'], '10.5', inplace=True)
df['Cone'].replace(['9 - 11', '9-11', '9 - 10 - 11', '10?'], '10', inplace=True)
df['Cone'].replace(['9 - 10', '9-10', '010-09', '9-=10'], '9.5', inplace=True)
df['Cone'].replace(['8 - 10', '8-10', '8 - 9 - 10', '8 - 9 - 10', '9 only'], '9', inplace=True)
df['Cone'].replace('8 - 9', '8.5', inplace=True)
df['Cone'].replace('7 - 9', '8', inplace=True)
df['Cone'].replace(['7 - 8', '7-8'], '7.5', inplace=True)
df['Cone'].replace(['6 - 10', '6-10', '7 - 10', '9 - 12', '6 - 9', '5-9', '04 - 12', '5 - 10', '5-10', '6, 7, 8, 9, 10'], np.NaN, inplace=True)
df['Cone'].value_counts()
# Out:
# 10      311
# 9.5     249
# 9       113
# 8        18
# 10.5     15
# 11        8
# 8.5       4
# 7         2
# 7.5       1
# 6         1
# Name: Cone, dtype: int64

# %% [markdown]
# # Color

# %%
df['Color'].value_counts()
# Out:
# White                             75
# Black                             24
# Clear                             23
# black                             19
# green                             19
# Blue                              16
# Amber                             15
# Green                             14
# Tan                               13
# Red                               13
# white                             12
# Brown                             11
# orange                            10
# blue                               9
# Yellow                             9
# Orange                             9
# iron red brown                     9
# rutile blue                        6
# clear                              6
# light green                        5
# Purple                             5
# yellow                             5
# Gray                               5
# Plum to black                      5
# copper red                         5
# dark blue                          4
# red                                4
# Bronze metallic                    4
# Yellow Opaque                      3
# blue brown                         3
#                                   ..
# Opaque White                       1
# translucent white                  1
# Red Red-Brown                      1
# on porcelain in OX THIN = warm     1
# Rust to Yellow                     1
# White Semi-Opaque                  1
# Grey-blue to black                 1
# green black                        1
# red brown                          1
# Black w/ silver spots              1
# black w/brown spots                1
# gray/blue                          1
# Off-white                          1
# Cream white                        1
# royal blue                         1
# slightly grey                      1
# light blue green                   1
# Metallic Bronze                    1
# chun blue to white opaque          1
# light blue                         1
# blue to rust                       1
# Black Opaque                       1
# grey-green                         1
# Brown to black                     1
# Light tan                          1
# slate blue                         1
# Cream White Opaque                 1
# dark green with iron               1
# Translucent Green                  1
# white as base                      1
# Name: Color, Length: 217, dtype: int64

# %%
df['Color'] = df['Color'].str.lower()
tmp = []
threshold = df.shape[0]/100
for i in range(df['Color'].nunique()):
    if df['Color'].value_counts(sort=False)[i] < threshold:
        tmp.append(df['Color'].value_counts(sort=False).index[i])
len(tmp)
# Out:
# 185

# %%
df['Color'].replace(tmp, np.NaN, inplace=True)
sns.countplot(df['Color'].value_counts())

# %%
df['Color'].value_counts()
# Out:
# white             87
# black             43
# green             33
# clear             29
# blue              25
# orange            19
# red               17
# amber             15
# tan               14
# yellow            14
# brown             13
# iron red brown     9
# Name: Color, dtype: int64

# %% [markdown]
# # Testing

# %%
df['Testing'] = df['Testing'].str.lower()
df['Testing'].value_counts()
# Out:
# untested    238
# tested       44
# Name: Testing, dtype: int64

# %% [markdown]
# # Surface

# %%
df['Surface'].value_counts()
# Out:
# Gloss                   119
# Satin matt               70
# Semi-gloss               31
# glossy                   29
# Matt                     23
# unglazed                 23
# glossy shiny             20
# matte                    20
# Waxy                     19
# Glossy                   19
# Shiny or Glossy          16
# shiny glossy             14
# satin matte              12
# ?                        10
# Matte                     9
# glossy, shiny             9
# shiny, glossy             8
# Unglazed                  7
# Satin Matt                5
# gloss                     5
# slip or engobe            5
# satin matt                5
# Glossy Satin              5
# Metallic                  5
# matt                      5
# Satin                     4
# semi-matte                4
# satin                     4
# satin to gloss            4
# Stoney Matt               4
#                        ...
# satin to glossy           2
# ash-like                  2
# semimatt                  2
# Satin Matte               2
# Satin-Matt                2
# Crawl                     2
# slip                      2
# semimatte                 2
# Glossy and Matt           2
# semi matte                2
# Sensuous Satin matt       1
# semi-matt                 1
# dry matte                 1
# Matt Stony                1
# Dry Matt                  1
# shiny                     1
# dry matt                  1
# Dry Matte                 1
# macro crystalline         1
# Semi-Matte or Satin       1
# fat waxy satin matt       1
# gloss stable              1
# fluid glossy, shiny       1
# Smooth Dry Matt           1
# Smooth Matt               1
# stable                    1
# gloss w/ crystalline      1
# glassy                    1
# Matte Satin               1
# Streaky                   1
# Name: Surface, Length: 66, dtype: int64

# %%
df['Surface'] = df['Surface'].str.lower()
tmp = []
threshold = df.shape[0]/100
for i in range(df['Surface'].nunique()):
    if df['Surface'].value_counts(sort=False)[i] < threshold:
        tmp.append(df['Surface'].value_counts(sort=False).index[i])
len(tmp)
# Out:
# 37

# %%
df['Surface'].replace(tmp, np.NaN, inplace=True)
sns.countplot(df['Surface'].value_counts())

# %%
df['Surface'].value_counts()
# Out:
# gloss              124
# satin matt          80
# glossy              48
# semi-gloss          31
# unglazed            30
# matte               29
# matt                28
# glossy shiny        20
# waxy                19
# shiny or glossy     16
# shiny glossy        14
# satin matte         14
# ?                   10
# glossy, shiny        9
# shiny, glossy        8
# satin                8
# slip or engobe       8
# Name: Surface, dtype: int64

# %%
df['Surface'].replace('?', np.NAN, inplace=True)
df['Surface'].replace('gloss', 'glossy', inplace=True)
df['Surface'].replace('matt', 'matte', inplace=True)
df['Surface'].replace('satin matt', 'satin matte', inplace=True)
df['Surface'].replace(['shiny or glossy', 'shiny glossy', 'glossy, shiny', 'shiny, glossy'], 'glossy shiny', inplace=True)

# %%
df['Surface'].value_counts()
# Out:
# glossy            172
# satin matte        94
# glossy shiny       67
# matte              57
# semi-gloss         31
# unglazed           30
# waxy               19
# satin               8
# slip or engobe      8
# Name: Surface, dtype: int64

# %% [markdown]
# # Firing

# %%
df['Firing'] = df['Firing'].str.lower()
df['Firing'].value_counts()
# Out:
# reduction              383
# ox. or red.            166
# oxidation               39
# salt - soda             16
# ox or red               10
# wood                     6
# salt                     5
# soda                     4
# ox. or red. or soda      2
# reduction o              1
# soda salt                1
# Name: Firing, dtype: int64

# %%
df['Firing'].replace('ox or red', 'ox. or red.', inplace=True)
df['Firing'].replace(['salt', 'soda'], 'salt - soda', inplace=True)
df['Firing'].replace('reduction o', 'reduction', inplace=True)

# %%
df['Firing'].value_counts()
# Out:
# reduction              384
# ox. or red.            176
# oxidation               39
# salt - soda             25
# wood                     6
# ox. or red. or soda      2
# soda salt                1
# Name: Firing, dtype: int64

# %%
df['Firing'] = df['Firing'].str.lower()
tmp = []
threshold = df.shape[0]/100
for i in range(df['Firing'].nunique()):
    if df['Firing'].value_counts(sort=False)[i] < threshold:
        tmp.append(df['Firing'].value_counts(sort=False).index[i])
len(tmp)
# Out:
# 3

# %%
df['Firing'].replace(tmp, np.NaN, inplace=True)
sns.countplot(df['Firing'].value_counts())

# %%
df['Firing'].value_counts()
# Out:
# reduction      384
# ox. or red.    176
# oxidation       39
# salt - soda     25
# Name: Firing, dtype: int64

# %% [markdown]
# # Transparency

# %%
df['Transparency'] = df['Transparency'].str.lower()
df['Transparency'].value_counts()
# Out:
# opaque         221
# transparent     69
# semi-opaque     50
# translucent     41
# Name: Transparency, dtype: int64

# %%
df['Transparency'].replace('translucent', 'semi-opaque', inplace=True)

# %%
df['Transparency'].value_counts()
# Out:
# opaque         221
# semi-opaque     91
# transparent     69
# Name: Transparency, dtype: int64

# %% [markdown]
# # Recipe

# %%
recipe = []

# %%
ingredients = []
for col in df.columns:
    if col.startswith('Recipe'):
        for ix in range(df.shape[0]):
            ingredients.append(str(df[col][ix]).split('\t'))
df_ingredients = pd.DataFrame(ingredients)
df_ingredients.columns = ['ingredient', 'amount']

# %%
df_ingredients
# Out:
#                   ingredient amount
# 0                      Flint  40.40
# 1                   Feldspar  35.00
# 2                     Kaolin   9.50
# 3            Custer feldspar  26.00
# 4            Custer feldspar  46.00
# 5          Nepheline syenite  35.00
# 6                Albany slip  63.16
# 7                     Redart  72.00
# 8                   Feldspar  62.50
# 9                   Feldspar  20.00
# 10                  Feldspar  51.71
# 11          Barium carbonate  36.60
# 12       Strontium carbonate  27.50
# 13              Barnard clay  33.00
# 14               Albany Slip  36.00
# 15                  Wood ash  22.00
# 16           Custer feldspar  26.50
# 17      Kaolin - theoretical  15.00
# 18      Kaolin - theoretical  12.00
# 19           Custer feldspar  19.00
# 20              Alberta slip  35.50
# 21           Custer feldspar  30.00
# 22    feldspar - theoretical  25.60
# 23               Albany slip  35.90
# 24              Alberta slip  77.00
# 25                       EPK  14.00
# 26                  Feldspar  47.90
# 27                  Feldspar  47.70
# 28         Nepheline syenite  34.10
# 29             Soda feldspar  57.13
# ...                      ...    ...
# 9733                     nan   None
# 9734                     nan   None
# 9735                     nan   None
# 9736                     nan   None
# 9737                     nan   None
# 9738                     nan   None
# 9739                     nan   None
# 9740                     nan   None
# 9741                     nan   None
# 9742                     nan   None
# 9743                     nan   None
# 9744                     nan   None
# 9745                     nan   None
# 9746                     nan   None
# 9747                     nan   None
# 9748                     nan   None
# 9749                     nan   None
# 9750                     nan   None
# 9751                     nan   None
# 9752                     nan   None
# 9753                     nan   None
# 9754                     nan   None
# 9755                     nan   None
# 9756                     nan   None
# 9757                     nan   None
# 9758                     nan   None
# 9759                     nan   None
# 9760                     nan   None
# 9761                     nan   None
# 9762                     nan   None
#
# [9763 rows x 2 columns]

# %%
df_ingredients['ingredient'] = df_ingredients['ingredient'].str.lower()
df_ingredients['ingredient'].unique()
len(df_ingredients['ingredient'].unique())
# Out:
# 223

# %%
for col in df.columns:
    if col.startswith('Recipe'):
        df.drop(str(col), axis=1, inplace=True)

# %%
df
# Out:
#                                        Glaze name  Cone   Color   Testing  \
# 0                                    blue lithium   9.5    blue       NaN
# 1                                    yellow lewis    10     NaN       NaN
# 2                                  blue limestone    10     NaN       NaN
# 3                                     purple chun    10     NaN       NaN
# 4        matt strontium crystal magic steven hill    10   white       NaN
# 5                                          #207.3     8     NaN       NaN
# 6                                    albany glaze   9.5     NaN       NaN
# 7                albany slip substitute hendley's   NaN     NaN       NaN
# 8                            alkaline high fire 1   9.5   clear       NaN
# 9                            alkaline high fire 2    10     NaN       NaN
# 10                     alkaline high fire 2 no cs    10     NaN       NaN
# 11                           alkaline lee rexrode     9   white       NaN
# 12                        alkaline lee rexrode sr     9   white       NaN
# 13                                  amber barnard    10   amber       NaN
# 14                                  amber celadon   9.5     NaN  untested
# 15                   amber celadon mckenzie smith   9.5   amber       NaN
# 16                     amber celadon nick's ochre    10   amber       NaN
# 17                       amber celadon no  albany   9.5     NaN  untested
# 18                        amber celadon no albany   9.5     NaN  untested
# 19                     amber celadon vc no albany    10   amber       NaN
# 20                   amber celadon w/alberta slip    10     NaN       NaN
# 21                                 amber gulden's    10   amber       NaN
# 22                           amber gulden's no gb    10   amber       NaN
# 23                      amber shaner celadon arac   9.5   amber       NaN
# 24              amber shaner celadon arac alberta   9.5   amber       NaN
# 25            amber shaner celadon arac no albany   9.5   brown    tested
# 26                            amber stable test 1    10   amber       NaN
# 27                 amber stable test 2 w/bone ash    10   amber       NaN
# 28                            amber theoretical 3    10   amber  untested
# 29                                  anderson blue   9.5     NaN       NaN
# ..                                            ...   ...     ...       ...
# 721                                      white pv     9   white       NaN
# 722                      white satin matt orielly   9.5   white       NaN
# 723                  white satin matte margaret's     9   white       NaN
# 724  white satin matte margaret's glaze calc prob     9   white       NaN
# 725                               white semi-matt    10   white       NaN
# 726                                   white shiny   9.5   white       NaN
# 727                                  white sperry    10   white       NaN
# 728                                white sycamore   9.5   white       NaN
# 729                                  white temple    10   white       NaN
# 730                               white v.c. matt   9.5   white  untested
# 731                                    white waxy   NaN   white  untested
# 732                               white waxy matt    10   white  untested
# 733                                white yanigara  10.5   white       NaN
# 734                                      woo base   9.5     NaN  untested
# 735                                  yellow amber    10   amber       NaN
# 736                           yellow amber martin    10     NaN       NaN
# 737                                    yellow ame    10     NaN       NaN
# 738                                   yellow ferg    10     NaN       NaN
# 739                                   yellow ferg    10  yellow       NaN
# 740                      yellow gwashington lewis    10  yellow       NaN
# 741                                 yellow korman   9.5  yellow  untested
# 742                                  yellow lewis    10  yellow       NaN
# 743                           yellow lewis rr rev    10  yellow       NaN
# 744                              yellow matt flow   9.5  yellow       NaN
# 745                             yellow salt horie    10  yellow       NaN
# 746                             yellow school bus    10  yellow       NaN
# 747                                yellow winokur    10     NaN  untested
# 748                                    yellow woo   9.5     NaN  untested
# 749                                 yellow woo #2   9.5  yellow       NaN
# 750                                         zello    10  yellow       NaN
#
#           Surface       Firing Transparency
# 0      semi-gloss  ox. or red.       opaque
# 1     satin matte    reduction          NaN
# 2      semi-gloss    reduction          NaN
# 3          glossy    reduction       opaque
# 4     satin matte    reduction       opaque
# 5          glossy    oxidation          NaN
# 6             NaN          NaN          NaN
# 7          glossy  ox. or red.          NaN
# 8          glossy  ox. or red.  transparent
# 9          glossy  ox. or red.  transparent
# 10         glossy  ox. or red.  transparent
# 11    satin matte    oxidation  semi-opaque
# 12    satin matte    oxidation  semi-opaque
# 13         glossy    reduction  transparent
# 14         glossy    reduction          NaN
# 15         glossy    reduction  transparent
# 16         glossy    reduction  transparent
# 17         glossy    reduction          NaN
# 18         glossy    reduction          NaN
# 19         glossy    reduction  semi-opaque
# 20         glossy    reduction  transparent
# 21         glossy    reduction  semi-opaque
# 22         glossy    reduction  semi-opaque
# 23         glossy    reduction  transparent
# 24         glossy    reduction  transparent
# 25         glossy    reduction  transparent
# 26         glossy    reduction  transparent
# 27         glossy    reduction  transparent
# 28         glossy    reduction  transparent
# 29          matte    reduction          NaN
# ..            ...          ...          ...
# 721  glossy shiny          NaN       opaque
# 722         satin  ox. or red.       opaque
# 723   satin matte    oxidation  semi-opaque
# 724   satin matte    oxidation  semi-opaque
# 725           NaN    reduction  semi-opaque
# 726        glossy    reduction  semi-opaque
# 727        glossy    reduction       opaque
# 728        glossy  ox. or red.       opaque
# 729          waxy          NaN       opaque
# 730   satin matte  ox. or red.  semi-opaque
# 731           NaN  ox. or red.       opaque
# 732          waxy  ox. or red.  semi-opaque
# 733   satin matte    reduction       opaque
# 734           NaN    reduction          NaN
# 735        glossy  salt - soda       opaque
# 736           NaN          NaN          NaN
# 737           NaN          NaN          NaN
# 738   satin matte    reduction          NaN
# 739   satin matte    reduction       opaque
# 740         matte    reduction       opaque
# 741         matte    reduction       opaque
# 742         matte    reduction          NaN
# 743         matte    reduction          NaN
# 744         matte    reduction       opaque
# 745        glossy  salt - soda       opaque
# 746        glossy  ox. or red.       opaque
# 747         matte    reduction          NaN
# 748           NaN    reduction          NaN
# 749         matte          NaN          NaN
# 750        glossy  salt - soda  transparent
#
# [751 rows x 7 columns]

# %%
for ingredient in df_ingredients['ingredient'].unique():
    df[ingredient] = np.NaN

# %%
for iing in range(int(len(df_ingredients)/len(df))):
    for ix in range(len(df)):
        ingredient = df_ingredients['ingredient'][len(df)*iing + ix]
        amount = df_ingredients['amount'][len(df)*iing + ix]
        df[ingredient][ix] = amount
# Out:
# /Users/a0082273/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df
# Out:
#                                        Glaze name  Cone   Color   Testing  \
# 0                                    blue lithium   9.5    blue       NaN
# 1                                    yellow lewis    10     NaN       NaN
# 2                                  blue limestone    10     NaN       NaN
# 3                                     purple chun    10     NaN       NaN
# 4        matt strontium crystal magic steven hill    10   white       NaN
# 5                                          #207.3     8     NaN       NaN
# 6                                    albany glaze   9.5     NaN       NaN
# 7                albany slip substitute hendley's   NaN     NaN       NaN
# 8                            alkaline high fire 1   9.5   clear       NaN
# 9                            alkaline high fire 2    10     NaN       NaN
# 10                     alkaline high fire 2 no cs    10     NaN       NaN
# 11                           alkaline lee rexrode     9   white       NaN
# 12                        alkaline lee rexrode sr     9   white       NaN
# 13                                  amber barnard    10   amber       NaN
# 14                                  amber celadon   9.5     NaN  untested
# 15                   amber celadon mckenzie smith   9.5   amber       NaN
# 16                     amber celadon nick's ochre    10   amber       NaN
# 17                       amber celadon no  albany   9.5     NaN  untested
# 18                        amber celadon no albany   9.5     NaN  untested
# 19                     amber celadon vc no albany    10   amber       NaN
# 20                   amber celadon w/alberta slip    10     NaN       NaN
# 21                                 amber gulden's    10   amber       NaN
# 22                           amber gulden's no gb    10   amber       NaN
# 23                      amber shaner celadon arac   9.5   amber       NaN
# 24              amber shaner celadon arac alberta   9.5   amber       NaN
# 25            amber shaner celadon arac no albany   9.5   brown    tested
# 26                            amber stable test 1    10   amber       NaN
# 27                 amber stable test 2 w/bone ash    10   amber       NaN
# 28                            amber theoretical 3    10   amber  untested
# 29                                  anderson blue   9.5     NaN       NaN
# ..                                            ...   ...     ...       ...
# 721                                      white pv     9   white       NaN
# 722                      white satin matt orielly   9.5   white       NaN
# 723                  white satin matte margaret's     9   white       NaN
# 724  white satin matte margaret's glaze calc prob     9   white       NaN
# 725                               white semi-matt    10   white       NaN
# 726                                   white shiny   9.5   white       NaN
# 727                                  white sperry    10   white       NaN
# 728                                white sycamore   9.5   white       NaN
# 729                                  white temple    10   white       NaN
# 730                               white v.c. matt   9.5   white  untested
# 731                                    white waxy   NaN   white  untested
# 732                               white waxy matt    10   white  untested
# 733                                white yanigara  10.5   white       NaN
# 734                                      woo base   9.5     NaN  untested
# 735                                  yellow amber    10   amber       NaN
# 736                           yellow amber martin    10     NaN       NaN
# 737                                    yellow ame    10     NaN       NaN
# 738                                   yellow ferg    10     NaN       NaN
# 739                                   yellow ferg    10  yellow       NaN
# 740                      yellow gwashington lewis    10  yellow       NaN
# 741                                 yellow korman   9.5  yellow  untested
# 742                                  yellow lewis    10  yellow       NaN
# 743                           yellow lewis rr rev    10  yellow       NaN
# 744                              yellow matt flow   9.5  yellow       NaN
# 745                             yellow salt horie    10  yellow       NaN
# 746                             yellow school bus    10  yellow       NaN
# 747                                yellow winokur    10     NaN  untested
# 748                                    yellow woo   9.5     NaN  untested
# 749                                 yellow woo #2   9.5  yellow       NaN
# 750                                         zello    10  yellow       NaN
#
#           Surface       Firing Transparency  Flint  Feldspar  Kaolin  \
# 0      semi-gloss  ox. or red.       opaque  40.40       NaN    3.00
# 1     satin matte    reduction          NaN   5.00     35.00     NaN
# 2      semi-gloss    reduction          NaN    NaN     38.10    9.50
# 3          glossy    reduction       opaque  29.50       NaN     NaN
# 4     satin matte    reduction       opaque    NaN       NaN     NaN
# 5          glossy    oxidation          NaN    NaN       NaN     NaN
# 6             NaN          NaN          NaN    NaN       NaN     NaN
# 7          glossy  ox. or red.          NaN    NaN       NaN     NaN
# 8          glossy  ox. or red.  transparent  24.60     62.50     NaN
# 9          glossy  ox. or red.  transparent  15.00     20.00     NaN
# 10         glossy  ox. or red.  transparent    NaN     51.71     NaN
# 11    satin matte    oxidation  semi-opaque   9.50       NaN     NaN
# 12    satin matte    oxidation  semi-opaque   9.50       NaN     NaN
# 13         glossy    reduction  transparent    NaN       NaN     NaN
# 14         glossy    reduction          NaN  14.00       NaN     NaN
# 15         glossy    reduction  transparent  17.00       NaN     NaN
# 16         glossy    reduction  transparent  25.60       NaN     NaN
# 17         glossy    reduction          NaN    NaN       NaN     NaN
# 18         glossy    reduction          NaN    NaN       NaN     NaN
# 19         glossy    reduction  semi-opaque  10.00       NaN     NaN
# 20         glossy    reduction  transparent    NaN       NaN     NaN
# 21         glossy    reduction  semi-opaque  25.00       NaN     NaN
# 22         glossy    reduction  semi-opaque    NaN       NaN     NaN
# 23         glossy    reduction  transparent  14.10       NaN     NaN
# 24         glossy    reduction  transparent    NaN       NaN     NaN
# 25         glossy    reduction  transparent    NaN       NaN     NaN
# 26         glossy    reduction  transparent    NaN     47.90     NaN
# 27         glossy    reduction  transparent    NaN     47.70     NaN
# 28         glossy    reduction  transparent    NaN       NaN     NaN
# 29          matte    reduction          NaN    NaN       NaN     NaN
# ..            ...          ...          ...    ...       ...     ...
# 721  glossy shiny          NaN       opaque    NaN       NaN     NaN
# 722         satin  ox. or red.       opaque  11.00       NaN     NaN
# 723   satin matte    oxidation  semi-opaque  19.00       NaN    5.00
# 724   satin matte    oxidation  semi-opaque    NaN       NaN     NaN
# 725           NaN    reduction  semi-opaque    NaN       NaN     NaN
# 726        glossy    reduction  semi-opaque  21.00       NaN     NaN
# 727        glossy    reduction       opaque    NaN       NaN     NaN
# 728        glossy  ox. or red.       opaque  19.10       NaN     NaN
# 729          waxy          NaN       opaque  19.61       NaN     NaN
# 730   satin matte  ox. or red.  semi-opaque  12.00       NaN     NaN
# 731           NaN  ox. or red.       opaque    NaN       NaN     NaN
# 732          waxy  ox. or red.  semi-opaque  23.86       NaN    5.68
# 733   satin matte    reduction       opaque    NaN       NaN     NaN
# 734           NaN    reduction          NaN   7.00       NaN     NaN
# 735        glossy  salt - soda       opaque  31.50       NaN     NaN
# 736           NaN          NaN          NaN    NaN       NaN     NaN
# 737           NaN          NaN          NaN    NaN       NaN     NaN
# 738   satin matte    reduction          NaN    NaN       NaN   22.20
# 739   satin matte    reduction       opaque    NaN       NaN   22.20
# 740         matte    reduction       opaque    NaN       NaN     NaN
# 741         matte    reduction       opaque  10.00       NaN     NaN
# 742         matte    reduction          NaN    NaN       NaN     NaN
# 743         matte    reduction          NaN    NaN       NaN     NaN
# 744         matte    reduction       opaque  14.00       NaN     NaN
# 745        glossy  salt - soda       opaque    NaN       NaN     NaN
# 746        glossy  ox. or red.       opaque  16.00       NaN     NaN
# 747         matte    reduction          NaN    NaN       NaN     NaN
# 748           NaN    reduction          NaN   7.00       NaN     NaN
# 749         matte          NaN          NaN    NaN       NaN     NaN
# 750        glossy  salt - soda  transparent    NaN       NaN     NaN
#
#                ...             Cerdec Intensive Red stain  Ilmenite, Powdered  \
# 0              ...                                    NaN                 NaN
# 1              ...                                    NaN                 NaN
# 2              ...                                    NaN                 NaN
# 3              ...                                    NaN                 NaN
# 4              ...                                    NaN                 NaN
# 5              ...                                    NaN                 NaN
# 6              ...                                    NaN                 NaN
# 7              ...                                    NaN                 NaN
# 8              ...                                    NaN                 NaN
# 9              ...                                    NaN                 NaN
# 10             ...                                    NaN                 NaN
# 11             ...                                    NaN                 NaN
# 12             ...                                    NaN                 NaN
# 13             ...                                    NaN                 NaN
# 14             ...                                    NaN                 NaN
# 15             ...                                    NaN                 NaN
# 16             ...                                    NaN                 NaN
# 17             ...                                    NaN                 NaN
# 18             ...                                    NaN                 NaN
# 19             ...                                    NaN                 NaN
# 20             ...                                    NaN                 NaN
# 21             ...                                    NaN                 NaN
# 22             ...                                    NaN                 NaN
# 23             ...                                    NaN                 NaN
# 24             ...                                    NaN                 NaN
# 25             ...                                    NaN                 NaN
# 26             ...                                    NaN                 NaN
# 27             ...                                    NaN                 NaN
# 28             ...                                    NaN                 NaN
# 29             ...                                    NaN                 NaN
# ..             ...                                    ...                 ...
# 721            ...                                    NaN                 NaN
# 722            ...                                    NaN                 NaN
# 723            ...                                    NaN                 NaN
# 724            ...                                    NaN                 NaN
# 725            ...                                    NaN                 NaN
# 726            ...                                    NaN                 NaN
# 727            ...                                    NaN                 NaN
# 728            ...                                    NaN                 NaN
# 729            ...                                    NaN                 NaN
# 730            ...                                    NaN                 NaN
# 731            ...                                    NaN                 NaN
# 732            ...                                    NaN                 NaN
# 733            ...                                    NaN                 NaN
# 734            ...                                    NaN                 NaN
# 735            ...                                    NaN                 NaN
# 736            ...                                    NaN                 NaN
# 737            ...                                    NaN                 NaN
# 738            ...                                    NaN                 NaN
# 739            ...                                    NaN                 NaN
# 740            ...                                    NaN                 NaN
# 741            ...                                    NaN                 NaN
# 742            ...                                    NaN                 NaN
# 743            ...                                    NaN                 NaN
# 744            ...                                    NaN                 NaN
# 745            ...                                    NaN                 NaN
# 746            ...                                    NaN                 NaN
# 747            ...                                    NaN                 NaN
# 748            ...                                    NaN                 NaN
# 749            ...                                    NaN                 NaN
# 750            ...                                    NaN                 NaN
#
#      yellow stain  snno  Granular ilmenite  Granular Manganese  \
# 0             NaN   NaN                NaN                 NaN
# 1             NaN   NaN                NaN                 NaN
# 2             NaN   NaN                NaN                 NaN
# 3             NaN   NaN                NaN                 NaN
# 4             NaN   NaN                NaN                 NaN
# 5             NaN   NaN                NaN                 NaN
# 6             NaN   NaN                NaN                 NaN
# 7             NaN   NaN                NaN                 NaN
# 8             NaN   NaN                NaN                 NaN
# 9             NaN   NaN                NaN                 NaN
# 10            NaN   NaN                NaN                 NaN
# 11            NaN   NaN                NaN                 NaN
# 12            NaN   NaN                NaN                 NaN
# 13            NaN   NaN                NaN                 NaN
# 14            NaN   NaN                NaN                 NaN
# 15            NaN   NaN                NaN                 NaN
# 16            NaN   NaN                NaN                 NaN
# 17            NaN   NaN                NaN                 NaN
# 18            NaN   NaN                NaN                 NaN
# 19            NaN   NaN                NaN                 NaN
# 20            NaN   NaN                NaN                 NaN
# 21            NaN   NaN                NaN                 NaN
# 22            NaN   NaN                NaN                 NaN
# 23            NaN   NaN                NaN                 NaN
# 24            NaN   NaN                NaN                 NaN
# 25            NaN   NaN                NaN                 NaN
# 26            NaN   NaN                NaN                 NaN
# 27            NaN   NaN                NaN                 NaN
# 28            NaN   NaN                NaN                 NaN
# 29            NaN   NaN                NaN                 NaN
# ..            ...   ...                ...                 ...
# 721           NaN   NaN                NaN                 NaN
# 722           NaN   NaN                NaN                 NaN
# 723           NaN   NaN                NaN                 NaN
# 724           NaN   NaN                NaN                 NaN
# 725           NaN   NaN                NaN                 NaN
# 726           NaN   NaN                NaN                 NaN
# 727           NaN   NaN                NaN                 NaN
# 728           NaN   NaN                NaN                 NaN
# 729           NaN   NaN                NaN                 NaN
# 730           NaN   NaN                NaN                 NaN
# 731           NaN   NaN                NaN                 NaN
# 732           NaN   NaN                NaN                 NaN
# 733           NaN   NaN                NaN                 NaN
# 734           NaN   NaN                NaN                 NaN
# 735           NaN   NaN                NaN                 NaN
# 736           NaN   NaN                NaN                 NaN
# 737           NaN   NaN                NaN                 NaN
# 738           NaN   NaN                NaN                 NaN
# 739           NaN   NaN                NaN                 NaN
# 740           NaN   NaN                NaN                 NaN
# 741           NaN   NaN                NaN                 NaN
# 742           NaN   NaN                NaN                 NaN
# 743           NaN   NaN                NaN                 NaN
# 744           NaN   NaN                NaN                 NaN
# 745           NaN   NaN                NaN                 NaN
# 746           NaN   NaN                NaN                 NaN
# 747           NaN   NaN                NaN                 NaN
# 748           NaN   NaN                NaN                 NaN
# 749           NaN   NaN                NaN                 NaN
# 750           NaN   NaN                NaN                 NaN
#
#      Ilmenite (325 mesh best)  Ferric oxide  Nickel carbonate  \
# 0                         NaN           NaN               NaN
# 1                         NaN           NaN               NaN
# 2                         NaN           NaN               NaN
# 3                         NaN           NaN               NaN
# 4                         NaN           NaN               NaN
# 5                         NaN           NaN               NaN
# 6                         NaN           NaN               NaN
# 7                         NaN           NaN               NaN
# 8                         NaN           NaN               NaN
# 9                         NaN           NaN               NaN
# 10                        NaN           NaN               NaN
# 11                        NaN           NaN               NaN
# 12                        NaN           NaN               NaN
# 13                        NaN           NaN               NaN
# 14                        NaN           NaN               NaN
# 15                        NaN           NaN               NaN
# 16                        NaN           NaN               NaN
# 17                        NaN           NaN               NaN
# 18                        NaN           NaN               NaN
# 19                        NaN           NaN               NaN
# 20                        NaN           NaN               NaN
# 21                        NaN           NaN               NaN
# 22                        NaN           NaN               NaN
# 23                        NaN           NaN               NaN
# 24                        NaN           NaN               NaN
# 25                        NaN           NaN               NaN
# 26                        NaN           NaN               NaN
# 27                        NaN           NaN               NaN
# 28                        NaN           NaN               NaN
# 29                        NaN           NaN               NaN
# ..                        ...           ...               ...
# 721                       NaN           NaN               NaN
# 722                       NaN           NaN               NaN
# 723                       NaN           NaN               NaN
# 724                       NaN           NaN               NaN
# 725                       NaN           NaN               NaN
# 726                       NaN           NaN               NaN
# 727                       NaN           NaN               NaN
# 728                       NaN           NaN               NaN
# 729                       NaN           NaN               NaN
# 730                       NaN           NaN               NaN
# 731                       NaN           NaN               NaN
# 732                       NaN           NaN               NaN
# 733                       NaN           NaN               NaN
# 734                       NaN           NaN               NaN
# 735                       NaN           NaN               NaN
# 736                       NaN           NaN               NaN
# 737                       NaN           NaN               NaN
# 738                       NaN           NaN               NaN
# 739                       NaN           NaN               NaN
# 740                       NaN           NaN               NaN
# 741                       NaN           NaN               NaN
# 742                       NaN           NaN               NaN
# 743                       NaN           NaN               NaN
# 744                       NaN           NaN               NaN
# 745                       NaN           NaN               NaN
# 746                       NaN           NaN               NaN
# 747                       NaN           NaN               NaN
# 748                       NaN           NaN               NaN
# 749                       NaN           NaN               NaN
# 750                       NaN           NaN               NaN
#
#      Red iron oxide (Spanish)
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# ..                        ...
# 721                       NaN
# 722                       NaN
# 723                       NaN
# 724                       NaN
# 725                       NaN
# 726                       NaN
# 727                       NaN
# 728                       NaN
# 729                       NaN
# 730                       NaN
# 731                       NaN
# 732                       NaN
# 733                       NaN
# 734                       NaN
# 735                       NaN
# 736                       NaN
# 737                       NaN
# 738                       NaN
# 739                       NaN
# 740                       NaN
# 741                       NaN
# 742                       NaN
# 743                       NaN
# 744                       NaN
# 745                       NaN
# 746                       NaN
# 747                       NaN
# 748                       NaN
# 749                       NaN
# 750                       NaN
#
# [751 rows x 258 columns]

# %%
df_ingredients['ingredient'].str.lower().value_counts()
# Out:
# nan                         4992
# whiting                      466
# epk                          336
# flint                        303
# custer feldspar              211
# dolomite                     195
# silica                       194
# red iron oxide               177
# nepheline syenite            174
# bentonite                    144
# ball clay                    126
# talc                         101
# gerstley borate               97
# kaolin                        97
# cobalt carbonate              95
# barium carbonate              94
# zinc oxide                    87
# tin oxide                     81
# potash feldspar               81
# copper carbonate              79
# kona f-4 feldspar             78
# soda ash                      77
# spodumene                     75
# rutile                        74
# kentucky om #4                68
# bone ash                      53
# g-200 feldspar                52
# custer spar                   48
# cornwall stone                47
# manganese dioxide             46
#                             ...
# ferro 3134                     1
# cmc                            1
# kaolin georgia                 1
# chrome                         1
# fireclay                       1
# red iron oxide (spanish)       1
# neph sye                       1
# cobalt oxide, black            1
# yellow stain                   1
# ilmenite, powdered             1
# lincoln                        1
# granular ilmenite              1
# granular manganese             1
# nepheline sye                  1
# eutruia marl                   1
# ap green fireclay              1
# lepidolite                     1
# g22                            1
# feldspar - theoretical         1
# rutile (granular)              1
# ferric oxide                   1
# silica 200 mesh                1
# clay                           1
# talc (milled white)            1
# k-200  feldspar                1
# pemco frit p-25                1
# nc-4 feldspar                  1
# neph sy                        1
# black iron                     1
# zirconium silicate             1
# Name: ingredient, Length: 223, dtype: int64

# %%
tmp = []
threshold = df.shape[0]/100
for i in range(df_ingredients['ingredient'].nunique()):
    if df_ingredients['ingredient'].value_counts(sort=False)[i] < threshold:
        tmp.append(df_ingredients['ingredient'].value_counts(sort=False).index[i])
len(tmp)
# Out:
# 157

# %%
tmp.sort()

# %%
tmp
# Out:
# ['#6 tile clay',
#  'albany slip clay',
#  'alumina',
#  'alumina hydrate',
#  'amblygonite',
#  'ap green fireclay',
#  'ash wood',
#  'avery kaolin',
#  'barium carb',
#  'barnard slip',
#  'black copper oxide',
#  'black iron',
#  'black mason stain',
#  'black nickel oxide',
#  'black stain',
#  'borax',
#  'c & c',
#  'calcined zinc oxide',
#  'calcium carbonate',
#  'cedar heights goldart clay',
#  'cedar heights redart',
#  'cedar heights redart clay',
#  'cerdec intensive red stain',
#  'chrome',
#  'chromium oxide',
#  'clay',
#  'cmc',
#  'cobalt oxide, black',
#  'cryolite',
#  'darvan',
#  'epsom salts',
#  'eutruia marl',
#  'f-4 feldspar',
#  'f-4 spar',
#  'feldspar - theoretical',
#  'feldspar fff',
#  'feldspar theoretical',
#  'ferric oxide',
#  'ferro 3134',
#  'ferro frit 3110',
#  'ferro frit 3124',
#  'ferro frit 3269',
#  'fire clay',
#  'fireclay',
#  'flint (325m)',
#  'flint (silica)',
#  'flint, or quartz',
#  'foundry hill creme',
#  'frit 3124',
#  'frit 3185',
#  'frit 3195',
#  'frit p-25',
#  'g-200 spar',
#  'g22',
#  'georgia kaolin',
#  'gillespie borate',
#  'glomax',
#  'godfrey feldspar',
#  'granular ilmenite',
#  'granular manganese',
#  'green chrome oxide',
#  'grog',
#  'grog, fine',
#  'grog,150 mesh',
#  'grolleg clay',
#  'grolleg kaolin',
#  'hardwood ash',
#  'hawthorne bond',
#  'ilmenite',
#  'ilmenite (325 mesh best)',
#  'ilmenite, powdered',
#  'iron chromate',
#  'jackson ball',
#  'k-200  feldspar',
#  'k-200 spar',
#  'kaolin georgia',
#  'kaopaque',
#  'kentucky ball clay',
#  'kingman feldspar',
#  'kona f-4',
#  'kona f-4  spar',
#  'kona f-4 soda feldspar',
#  'kona feldspar',
#  'ky white glaze clay',
#  'kyanite',
#  'lepidolite',
#  'lincoln',
#  'lizella red',
#  'macaloid',
#  'magnesium carb',
#  'manganese carbonate',
#  'mason 6600 black stain',
#  'minspar soda feldspar',
#  'mixed hardwood ash',
#  'molochite',
#  'mullite',
#  'nc-4 feldspar',
#  'neph sy',
#  'neph sye',
#  'nepheline sye',
#  'newman red',
#  'nickel carbonate',
#  'nickel oxide',
#  'nsd',
#  'ochre',
#  'opax',
#  'pemco frit p-25',
#  'petalite',
#  'pine lake',
#  'plastic vitrox',
#  'potash feldspar - theoretical',
#  'potash spar',
#  'pyrax',
#  'pyrophyllite',
#  'pyrotrol',
#  'quartz',
#  'red art clay',
#  'red art clay calcined',
#  'red clay',
#  'red iron oxide (spanish)',
#  'rhyolite',
#  'rice hull ash',
#  'rutile (granular)',
#  'rutile (light)',
#  'rutile (powdered)',
#  'salt',
#  'silica (200m)',
#  'silica (a-25 best)',
#  'silica 200 mesh',
#  'silica, (325 mesh)',
#  'silica, 200 mesh',
#  'snno',
#  'soda ash (anhydrous)',
#  'soda spar',
#  'sodium silicate',
#  'softwood ash',
#  'superpax',
#  'talc (milled white)',
#  'talc (ny)',
#  'talc theoretical',
#  'tennessee #1',
#  'tennessee #1 ball clay',
#  'tennessee #10',
#  'tennessee #5 ball clay',
#  'tennessee ball clay',
#  'tin',
#  'titanium oxide',
#  'ultrox',
#  'velva cast',
#  'volcanic ash',
#  'xx sagger clay',
#  'yellow iron oxide',
#  'yellow stain',
#  'zinc oxide (calc.)',
#  'zinc oxide (calcined)',
#  'zirconium silicate',
#  'zircopax plus']

# %% [markdown]
# # modeling

# %%
sns.countplot(df['Color'].fillna('NaN'))

# %%
import math
for ix in range(len(df)):
    if type(df['Color'][ix]) == float:
        df.drop(index=ix, inplace=True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                                        Glaze name  Cone   Color   Testing  \
# 0                                    blue lithium   9.5    blue       NaN
# 1        matt strontium crystal magic steven hill    10   white       NaN
# 2                            alkaline high fire 1   9.5   clear       NaN
# 3                            alkaline lee rexrode     9   white       NaN
# 4                         alkaline lee rexrode sr     9   white       NaN
# 5                                   amber barnard    10   amber       NaN
# 6                    amber celadon mckenzie smith   9.5   amber       NaN
# 7                      amber celadon nick's ochre    10   amber       NaN
# 8                      amber celadon vc no albany    10   amber       NaN
# 9                                  amber gulden's    10   amber       NaN
# 10                           amber gulden's no gb    10   amber       NaN
# 11                      amber shaner celadon arac   9.5   amber       NaN
# 12              amber shaner celadon arac alberta   9.5   amber       NaN
# 13            amber shaner celadon arac no albany   9.5   brown    tested
# 14                            amber stable test 1    10   amber       NaN
# 15                 amber stable test 2 w/bone ash    10   amber       NaN
# 16                            amber theoretical 3    10   amber  untested
# 17                        andy martin's showsaver    10   clear       NaN
# 18                                    ash benji's     9     tan    tested
# 19                              ash benji's remix     9     tan    tested
# 20                            ash blue van gilder    10    blue       NaN
# 21                               ash cooter green   9.5   green       NaN
# 22                                  ash fake blue   9.5    blue       NaN
# 23                              ash felix's green     9   green    tested
# 24                                ash fresca base    10     tan       NaN
# 25                               ash green cooter   9.5   green  untested
# 26                               ash honey doug's    10   amber       NaN
# 27                                 ash pale green    10   green       NaN
# 28                                ash tom turners    10     tan       NaN
# 29                              ash, fake donna's     9   amber       NaN
# ..                                            ...   ...     ...       ...
# 288                          white hanlin's gloss    10   white       NaN
# 289                 white ian anderson's dynamite   9.5   white       NaN
# 290                                   white leach   9.5   white       NaN
# 291                                    white matt     9   white       NaN
# 292                           white opaque glossy   9.5   white       NaN
# 293             white pete's charlie ian anderson   9.5   clear       NaN
# 294                                      white pv     9   white       NaN
# 295                      white satin matt orielly   9.5   white       NaN
# 296                  white satin matte margaret's     9   white       NaN
# 297  white satin matte margaret's glaze calc prob     9   white       NaN
# 298                               white semi-matt    10   white       NaN
# 299                                   white shiny   9.5   white       NaN
# 300                                  white sperry    10   white       NaN
# 301                                white sycamore   9.5   white       NaN
# 302                                  white temple    10   white       NaN
# 303                               white v.c. matt   9.5   white  untested
# 304                                    white waxy   NaN   white  untested
# 305                               white waxy matt    10   white  untested
# 306                                white yanigara  10.5   white       NaN
# 307                                  yellow amber    10   amber       NaN
# 308                                   yellow ferg    10  yellow       NaN
# 309                      yellow gwashington lewis    10  yellow       NaN
# 310                                 yellow korman   9.5  yellow  untested
# 311                                  yellow lewis    10  yellow       NaN
# 312                           yellow lewis rr rev    10  yellow       NaN
# 313                              yellow matt flow   9.5  yellow       NaN
# 314                             yellow salt horie    10  yellow       NaN
# 315                             yellow school bus    10  yellow       NaN
# 316                                 yellow woo #2   9.5  yellow       NaN
# 317                                         zello    10  yellow       NaN
#
#           Surface       Firing Transparency  Flint  Feldspar  Kaolin  \
# 0      semi-gloss  ox. or red.       opaque  40.40       NaN    3.00
# 1     satin matte    reduction       opaque    NaN       NaN     NaN
# 2          glossy  ox. or red.  transparent  24.60     62.50     NaN
# 3     satin matte    oxidation  semi-opaque   9.50       NaN     NaN
# 4     satin matte    oxidation  semi-opaque   9.50       NaN     NaN
# 5          glossy    reduction  transparent    NaN       NaN     NaN
# 6          glossy    reduction  transparent  17.00       NaN     NaN
# 7          glossy    reduction  transparent  25.60       NaN     NaN
# 8          glossy    reduction  semi-opaque  10.00       NaN     NaN
# 9          glossy    reduction  semi-opaque  25.00       NaN     NaN
# 10         glossy    reduction  semi-opaque    NaN       NaN     NaN
# 11         glossy    reduction  transparent  14.10       NaN     NaN
# 12         glossy    reduction  transparent    NaN       NaN     NaN
# 13         glossy    reduction  transparent    NaN       NaN     NaN
# 14         glossy    reduction  transparent    NaN     47.90     NaN
# 15         glossy    reduction  transparent    NaN     47.70     NaN
# 16         glossy    reduction  transparent    NaN       NaN     NaN
# 17         glossy  ox. or red.  transparent  20.50       NaN     NaN
# 18    satin matte    reduction       opaque   4.00       NaN     NaN
# 19    satin matte    reduction       opaque   4.00       NaN     NaN
# 20            NaN    reduction  semi-opaque    NaN       NaN     NaN
# 21     semi-gloss    reduction  semi-opaque    NaN       NaN     NaN
# 22            NaN  ox. or red.          NaN    NaN       NaN     NaN
# 23           waxy    reduction       opaque    NaN       NaN     NaN
# 24           waxy    reduction  semi-opaque    NaN       NaN     NaN
# 25            NaN  salt - soda          NaN    NaN       NaN     NaN
# 26     semi-gloss    reduction  semi-opaque    NaN       NaN     NaN
# 27    satin matte    reduction  semi-opaque  20.00     10.00    6.00
# 28           waxy    reduction  semi-opaque    NaN       NaN     NaN
# 29    satin matte    reduction  semi-opaque    NaN       NaN     NaN
# ..            ...          ...          ...    ...       ...     ...
# 288        glossy          NaN       opaque  24.04       NaN   11.54
# 289   satin matte  ox. or red.       opaque    NaN       NaN     NaN
# 290           NaN  ox. or red.       opaque  30.00       NaN     NaN
# 291         matte          NaN          NaN  29.41     41.18   16.47
# 292        glossy  ox. or red.       opaque  30.00       NaN     NaN
# 293        glossy  ox. or red.  semi-opaque    NaN       NaN     NaN
# 294  glossy shiny          NaN       opaque    NaN       NaN     NaN
# 295         satin  ox. or red.       opaque  11.00       NaN     NaN
# 296   satin matte    oxidation  semi-opaque  19.00       NaN    5.00
# 297   satin matte    oxidation  semi-opaque    NaN       NaN     NaN
# 298           NaN    reduction  semi-opaque    NaN       NaN     NaN
# 299        glossy    reduction  semi-opaque  21.00       NaN     NaN
# 300        glossy    reduction       opaque    NaN       NaN     NaN
# 301        glossy  ox. or red.       opaque  19.10       NaN     NaN
# 302          waxy          NaN       opaque  19.61       NaN     NaN
# 303   satin matte  ox. or red.  semi-opaque  12.00       NaN     NaN
# 304           NaN  ox. or red.       opaque    NaN       NaN     NaN
# 305          waxy  ox. or red.  semi-opaque  23.86       NaN    5.68
# 306   satin matte    reduction       opaque    NaN       NaN     NaN
# 307        glossy  salt - soda       opaque  31.50       NaN     NaN
# 308   satin matte    reduction       opaque    NaN       NaN   22.20
# 309         matte    reduction       opaque    NaN       NaN     NaN
# 310         matte    reduction       opaque  10.00       NaN     NaN
# 311         matte    reduction          NaN    NaN       NaN     NaN
# 312         matte    reduction          NaN    NaN       NaN     NaN
# 313         matte    reduction       opaque  14.00       NaN     NaN
# 314        glossy  salt - soda       opaque    NaN       NaN     NaN
# 315        glossy  ox. or red.       opaque  16.00       NaN     NaN
# 316         matte          NaN          NaN    NaN       NaN     NaN
# 317        glossy  salt - soda  transparent    NaN       NaN     NaN
#
#                ...             Cerdec Intensive Red stain  Ilmenite, Powdered  \
# 0              ...                                    NaN                 NaN
# 1              ...                                    NaN                 NaN
# 2              ...                                    NaN                 NaN
# 3              ...                                    NaN                 NaN
# 4              ...                                    NaN                 NaN
# 5              ...                                    NaN                 NaN
# 6              ...                                    NaN                 NaN
# 7              ...                                    NaN                 NaN
# 8              ...                                    NaN                 NaN
# 9              ...                                    NaN                 NaN
# 10             ...                                    NaN                 NaN
# 11             ...                                    NaN                 NaN
# 12             ...                                    NaN                 NaN
# 13             ...                                    NaN                 NaN
# 14             ...                                    NaN                 NaN
# 15             ...                                    NaN                 NaN
# 16             ...                                    NaN                 NaN
# 17             ...                                    NaN                 NaN
# 18             ...                                    NaN                 NaN
# 19             ...                                    NaN                 NaN
# 20             ...                                    NaN                 NaN
# 21             ...                                    NaN                 NaN
# 22             ...                                    NaN                 NaN
# 23             ...                                    NaN                 NaN
# 24             ...                                    NaN                 NaN
# 25             ...                                    NaN                 NaN
# 26             ...                                    NaN                 NaN
# 27             ...                                    NaN                 NaN
# 28             ...                                    NaN                 NaN
# 29             ...                                    NaN                 NaN
# ..             ...                                    ...                 ...
# 288            ...                                    NaN                 NaN
# 289            ...                                    NaN                 NaN
# 290            ...                                    NaN                 NaN
# 291            ...                                    NaN                 NaN
# 292            ...                                    NaN                 NaN
# 293            ...                                    NaN                 NaN
# 294            ...                                    NaN                 NaN
# 295            ...                                    NaN                 NaN
# 296            ...                                    NaN                 NaN
# 297            ...                                    NaN                 NaN
# 298            ...                                    NaN                 NaN
# 299            ...                                    NaN                 NaN
# 300            ...                                    NaN                 NaN
# 301            ...                                    NaN                 NaN
# 302            ...                                    NaN                 NaN
# 303            ...                                    NaN                 NaN
# 304            ...                                    NaN                 NaN
# 305            ...                                    NaN                 NaN
# 306            ...                                    NaN                 NaN
# 307            ...                                    NaN                 NaN
# 308            ...                                    NaN                 NaN
# 309            ...                                    NaN                 NaN
# 310            ...                                    NaN                 NaN
# 311            ...                                    NaN                 NaN
# 312            ...                                    NaN                 NaN
# 313            ...                                    NaN                 NaN
# 314            ...                                    NaN                 NaN
# 315            ...                                    NaN                 NaN
# 316            ...                                    NaN                 NaN
# 317            ...                                    NaN                 NaN
#
#      yellow stain  snno  Granular ilmenite  Granular Manganese  \
# 0             NaN   NaN                NaN                 NaN
# 1             NaN   NaN                NaN                 NaN
# 2             NaN   NaN                NaN                 NaN
# 3             NaN   NaN                NaN                 NaN
# 4             NaN   NaN                NaN                 NaN
# 5             NaN   NaN                NaN                 NaN
# 6             NaN   NaN                NaN                 NaN
# 7             NaN   NaN                NaN                 NaN
# 8             NaN   NaN                NaN                 NaN
# 9             NaN   NaN                NaN                 NaN
# 10            NaN   NaN                NaN                 NaN
# 11            NaN   NaN                NaN                 NaN
# 12            NaN   NaN                NaN                 NaN
# 13            NaN   NaN                NaN                 NaN
# 14            NaN   NaN                NaN                 NaN
# 15            NaN   NaN                NaN                 NaN
# 16            NaN   NaN                NaN                 NaN
# 17            NaN   NaN                NaN                 NaN
# 18            NaN   NaN                NaN                 NaN
# 19            NaN   NaN                NaN                 NaN
# 20            NaN   NaN                NaN                 NaN
# 21            NaN   NaN                NaN                 NaN
# 22            NaN   NaN                NaN                 NaN
# 23            NaN   NaN                NaN                 NaN
# 24            NaN   NaN                NaN                 NaN
# 25            NaN   NaN                NaN                 NaN
# 26            NaN   NaN                NaN                 NaN
# 27            NaN   NaN                NaN                 NaN
# 28            NaN   NaN                NaN                 NaN
# 29            NaN   NaN                NaN                 NaN
# ..            ...   ...                ...                 ...
# 288           NaN   NaN                NaN                 NaN
# 289           NaN   NaN                NaN                 NaN
# 290           NaN   NaN                NaN                 NaN
# 291           NaN   NaN                NaN                 NaN
# 292           NaN   NaN                NaN                 NaN
# 293           NaN   NaN                NaN                 NaN
# 294           NaN   NaN                NaN                 NaN
# 295           NaN   NaN                NaN                 NaN
# 296           NaN   NaN                NaN                 NaN
# 297           NaN   NaN                NaN                 NaN
# 298           NaN   NaN                NaN                 NaN
# 299           NaN   NaN                NaN                 NaN
# 300           NaN   NaN                NaN                 NaN
# 301           NaN   NaN                NaN                 NaN
# 302           NaN   NaN                NaN                 NaN
# 303           NaN   NaN                NaN                 NaN
# 304           NaN   NaN                NaN                 NaN
# 305           NaN   NaN                NaN                 NaN
# 306           NaN   NaN                NaN                 NaN
# 307           NaN   NaN                NaN                 NaN
# 308           NaN   NaN                NaN                 NaN
# 309           NaN   NaN                NaN                 NaN
# 310           NaN   NaN                NaN                 NaN
# 311           NaN   NaN                NaN                 NaN
# 312           NaN   NaN                NaN                 NaN
# 313           NaN   NaN                NaN                 NaN
# 314           NaN   NaN                NaN                 NaN
# 315           NaN   NaN                NaN                 NaN
# 316           NaN   NaN                NaN                 NaN
# 317           NaN   NaN                NaN                 NaN
#
#      Ilmenite (325 mesh best)  Ferric oxide  Nickel carbonate  \
# 0                         NaN           NaN               NaN
# 1                         NaN           NaN               NaN
# 2                         NaN           NaN               NaN
# 3                         NaN           NaN               NaN
# 4                         NaN           NaN               NaN
# 5                         NaN           NaN               NaN
# 6                         NaN           NaN               NaN
# 7                         NaN           NaN               NaN
# 8                         NaN           NaN               NaN
# 9                         NaN           NaN               NaN
# 10                        NaN           NaN               NaN
# 11                        NaN           NaN               NaN
# 12                        NaN           NaN               NaN
# 13                        NaN           NaN               NaN
# 14                        NaN           NaN               NaN
# 15                        NaN           NaN               NaN
# 16                        NaN           NaN               NaN
# 17                        NaN           NaN               NaN
# 18                        NaN           NaN               NaN
# 19                        NaN           NaN               NaN
# 20                        NaN           NaN               NaN
# 21                        NaN           NaN               NaN
# 22                        NaN           NaN               NaN
# 23                        NaN           NaN               NaN
# 24                        NaN           NaN               NaN
# 25                        NaN           NaN               NaN
# 26                        NaN           NaN               NaN
# 27                        NaN           NaN               NaN
# 28                        NaN           NaN               NaN
# 29                        NaN           NaN               NaN
# ..                        ...           ...               ...
# 288                       NaN           NaN               NaN
# 289                       NaN           NaN               NaN
# 290                       NaN           NaN               NaN
# 291                       NaN           NaN               NaN
# 292                       NaN           NaN               NaN
# 293                       NaN           NaN               NaN
# 294                       NaN           NaN               NaN
# 295                       NaN           NaN               NaN
# 296                       NaN           NaN               NaN
# 297                       NaN           NaN               NaN
# 298                       NaN           NaN               NaN
# 299                       NaN           NaN               NaN
# 300                       NaN           NaN               NaN
# 301                       NaN           NaN               NaN
# 302                       NaN           NaN               NaN
# 303                       NaN           NaN               NaN
# 304                       NaN           NaN               NaN
# 305                       NaN           NaN               NaN
# 306                       NaN           NaN               NaN
# 307                       NaN           NaN               NaN
# 308                       NaN           NaN               NaN
# 309                       NaN           NaN               NaN
# 310                       NaN           NaN               NaN
# 311                       NaN           NaN               NaN
# 312                       NaN           NaN               NaN
# 313                       NaN           NaN               NaN
# 314                       NaN           NaN               NaN
# 315                       NaN           NaN               NaN
# 316                       NaN           NaN               NaN
# 317                       NaN           NaN               NaN
#
#      Red iron oxide (Spanish)
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# ..                        ...
# 288                       NaN
# 289                       NaN
# 290                       NaN
# 291                       NaN
# 292                       NaN
# 293                       NaN
# 294                       NaN
# 295                       NaN
# 296                       NaN
# 297                       NaN
# 298                       NaN
# 299                       NaN
# 300                       NaN
# 301                       NaN
# 302                       NaN
# 303                       NaN
# 304                       NaN
# 305                       NaN
# 306                       NaN
# 307                       NaN
# 308                       NaN
# 309                       NaN
# 310                       NaN
# 311                       NaN
# 312                       NaN
# 313                       NaN
# 314                       NaN
# 315                       NaN
# 316                       NaN
# 317                       NaN
#
# [318 rows x 258 columns]

# %%
sns.countplot(df['Color'].fillna('NaN'))

# %%
df['Ferric oxide'].value_counts()
# Out:
# 0.5    1
# Name: Ferric oxide, dtype: int64

# %%
df
# Out:
#                                        Glaze name  Cone   Color   Testing  \
# 0                                    blue lithium   9.5    blue       NaN
# 1                                    yellow lewis    10     NaN       NaN
# 2                                  blue limestone    10     NaN       NaN
# 3                                     purple chun    10     NaN       NaN
# 4        matt strontium crystal magic steven hill    10   white       NaN
# 5                                          #207.3     8     NaN       NaN
# 6                                    albany glaze   9.5     NaN       NaN
# 7                albany slip substitute hendley's   NaN     NaN       NaN
# 8                            alkaline high fire 1   9.5   clear       NaN
# 9                            alkaline high fire 2    10     NaN       NaN
# 10                     alkaline high fire 2 no cs    10     NaN       NaN
# 11                           alkaline lee rexrode     9   white       NaN
# 12                        alkaline lee rexrode sr     9   white       NaN
# 13                                  amber barnard    10   amber       NaN
# 14                                  amber celadon   9.5     NaN  untested
# 15                   amber celadon mckenzie smith   9.5   amber       NaN
# 16                     amber celadon nick's ochre    10   amber       NaN
# 17                       amber celadon no  albany   9.5     NaN  untested
# 18                        amber celadon no albany   9.5     NaN  untested
# 19                     amber celadon vc no albany    10   amber       NaN
# 20                   amber celadon w/alberta slip    10     NaN       NaN
# 21                                 amber gulden's    10   amber       NaN
# 22                           amber gulden's no gb    10   amber       NaN
# 23                      amber shaner celadon arac   9.5   amber       NaN
# 24              amber shaner celadon arac alberta   9.5   amber       NaN
# 25            amber shaner celadon arac no albany   9.5   brown    tested
# 26                            amber stable test 1    10   amber       NaN
# 27                 amber stable test 2 w/bone ash    10   amber       NaN
# 28                            amber theoretical 3    10   amber  untested
# 29                                  anderson blue   9.5     NaN       NaN
# ..                                            ...   ...     ...       ...
# 721                                      white pv     9   white       NaN
# 722                      white satin matt orielly   9.5   white       NaN
# 723                  white satin matte margaret's     9   white       NaN
# 724  white satin matte margaret's glaze calc prob     9   white       NaN
# 725                               white semi-matt    10   white       NaN
# 726                                   white shiny   9.5   white       NaN
# 727                                  white sperry    10   white       NaN
# 728                                white sycamore   9.5   white       NaN
# 729                                  white temple    10   white       NaN
# 730                               white v.c. matt   9.5   white  untested
# 731                                    white waxy   NaN   white  untested
# 732                               white waxy matt    10   white  untested
# 733                                white yanigara  10.5   white       NaN
# 734                                      woo base   9.5     NaN  untested
# 735                                  yellow amber    10   amber       NaN
# 736                           yellow amber martin    10     NaN       NaN
# 737                                    yellow ame    10     NaN       NaN
# 738                                   yellow ferg    10     NaN       NaN
# 739                                   yellow ferg    10  yellow       NaN
# 740                      yellow gwashington lewis    10  yellow       NaN
# 741                                 yellow korman   9.5  yellow  untested
# 742                                  yellow lewis    10  yellow       NaN
# 743                           yellow lewis rr rev    10  yellow       NaN
# 744                              yellow matt flow   9.5  yellow       NaN
# 745                             yellow salt horie    10  yellow       NaN
# 746                             yellow school bus    10  yellow       NaN
# 747                                yellow winokur    10     NaN  untested
# 748                                    yellow woo   9.5     NaN  untested
# 749                                 yellow woo #2   9.5  yellow       NaN
# 750                                         zello    10  yellow       NaN
#
#           Surface       Firing Transparency  Flint  Feldspar  Kaolin  \
# 0      semi-gloss  ox. or red.       opaque  40.40       NaN    3.00
# 1     satin matte    reduction          NaN   5.00     35.00     NaN
# 2      semi-gloss    reduction          NaN    NaN     38.10    9.50
# 3          glossy    reduction       opaque  29.50       NaN     NaN
# 4     satin matte    reduction       opaque    NaN       NaN     NaN
# 5          glossy    oxidation          NaN    NaN       NaN     NaN
# 6             NaN          NaN          NaN    NaN       NaN     NaN
# 7          glossy  ox. or red.          NaN    NaN       NaN     NaN
# 8          glossy  ox. or red.  transparent  24.60     62.50     NaN
# 9          glossy  ox. or red.  transparent  15.00     20.00     NaN
# 10         glossy  ox. or red.  transparent    NaN     51.71     NaN
# 11    satin matte    oxidation  semi-opaque   9.50       NaN     NaN
# 12    satin matte    oxidation  semi-opaque   9.50       NaN     NaN
# 13         glossy    reduction  transparent    NaN       NaN     NaN
# 14         glossy    reduction          NaN  14.00       NaN     NaN
# 15         glossy    reduction  transparent  17.00       NaN     NaN
# 16         glossy    reduction  transparent  25.60       NaN     NaN
# 17         glossy    reduction          NaN    NaN       NaN     NaN
# 18         glossy    reduction          NaN    NaN       NaN     NaN
# 19         glossy    reduction  semi-opaque  10.00       NaN     NaN
# 20         glossy    reduction  transparent    NaN       NaN     NaN
# 21         glossy    reduction  semi-opaque  25.00       NaN     NaN
# 22         glossy    reduction  semi-opaque    NaN       NaN     NaN
# 23         glossy    reduction  transparent  14.10       NaN     NaN
# 24         glossy    reduction  transparent    NaN       NaN     NaN
# 25         glossy    reduction  transparent    NaN       NaN     NaN
# 26         glossy    reduction  transparent    NaN     47.90     NaN
# 27         glossy    reduction  transparent    NaN     47.70     NaN
# 28         glossy    reduction  transparent    NaN       NaN     NaN
# 29          matte    reduction          NaN    NaN       NaN     NaN
# ..            ...          ...          ...    ...       ...     ...
# 721  glossy shiny          NaN       opaque    NaN       NaN     NaN
# 722         satin  ox. or red.       opaque  11.00       NaN     NaN
# 723   satin matte    oxidation  semi-opaque  19.00       NaN    5.00
# 724   satin matte    oxidation  semi-opaque    NaN       NaN     NaN
# 725           NaN    reduction  semi-opaque    NaN       NaN     NaN
# 726        glossy    reduction  semi-opaque  21.00       NaN     NaN
# 727        glossy    reduction       opaque    NaN       NaN     NaN
# 728        glossy  ox. or red.       opaque  19.10       NaN     NaN
# 729          waxy          NaN       opaque  19.61       NaN     NaN
# 730   satin matte  ox. or red.  semi-opaque  12.00       NaN     NaN
# 731           NaN  ox. or red.       opaque    NaN       NaN     NaN
# 732          waxy  ox. or red.  semi-opaque  23.86       NaN    5.68
# 733   satin matte    reduction       opaque    NaN       NaN     NaN
# 734           NaN    reduction          NaN   7.00       NaN     NaN
# 735        glossy  salt - soda       opaque  31.50       NaN     NaN
# 736           NaN          NaN          NaN    NaN       NaN     NaN
# 737           NaN          NaN          NaN    NaN       NaN     NaN
# 738   satin matte    reduction          NaN    NaN       NaN   22.20
# 739   satin matte    reduction       opaque    NaN       NaN   22.20
# 740         matte    reduction       opaque    NaN       NaN     NaN
# 741         matte    reduction       opaque  10.00       NaN     NaN
# 742         matte    reduction          NaN    NaN       NaN     NaN
# 743         matte    reduction          NaN    NaN       NaN     NaN
# 744         matte    reduction       opaque  14.00       NaN     NaN
# 745        glossy  salt - soda       opaque    NaN       NaN     NaN
# 746        glossy  ox. or red.       opaque  16.00       NaN     NaN
# 747         matte    reduction          NaN    NaN       NaN     NaN
# 748           NaN    reduction          NaN   7.00       NaN     NaN
# 749         matte          NaN          NaN    NaN       NaN     NaN
# 750        glossy  salt - soda  transparent    NaN       NaN     NaN
#
#                ...             Cerdec Intensive Red stain  Ilmenite, Powdered  \
# 0              ...                                    NaN                 NaN
# 1              ...                                    NaN                 NaN
# 2              ...                                    NaN                 NaN
# 3              ...                                    NaN                 NaN
# 4              ...                                    NaN                 NaN
# 5              ...                                    NaN                 NaN
# 6              ...                                    NaN                 NaN
# 7              ...                                    NaN                 NaN
# 8              ...                                    NaN                 NaN
# 9              ...                                    NaN                 NaN
# 10             ...                                    NaN                 NaN
# 11             ...                                    NaN                 NaN
# 12             ...                                    NaN                 NaN
# 13             ...                                    NaN                 NaN
# 14             ...                                    NaN                 NaN
# 15             ...                                    NaN                 NaN
# 16             ...                                    NaN                 NaN
# 17             ...                                    NaN                 NaN
# 18             ...                                    NaN                 NaN
# 19             ...                                    NaN                 NaN
# 20             ...                                    NaN                 NaN
# 21             ...                                    NaN                 NaN
# 22             ...                                    NaN                 NaN
# 23             ...                                    NaN                 NaN
# 24             ...                                    NaN                 NaN
# 25             ...                                    NaN                 NaN
# 26             ...                                    NaN                 NaN
# 27             ...                                    NaN                 NaN
# 28             ...                                    NaN                 NaN
# 29             ...                                    NaN                 NaN
# ..             ...                                    ...                 ...
# 721            ...                                    NaN                 NaN
# 722            ...                                    NaN                 NaN
# 723            ...                                    NaN                 NaN
# 724            ...                                    NaN                 NaN
# 725            ...                                    NaN                 NaN
# 726            ...                                    NaN                 NaN
# 727            ...                                    NaN                 NaN
# 728            ...                                    NaN                 NaN
# 729            ...                                    NaN                 NaN
# 730            ...                                    NaN                 NaN
# 731            ...                                    NaN                 NaN
# 732            ...                                    NaN                 NaN
# 733            ...                                    NaN                 NaN
# 734            ...                                    NaN                 NaN
# 735            ...                                    NaN                 NaN
# 736            ...                                    NaN                 NaN
# 737            ...                                    NaN                 NaN
# 738            ...                                    NaN                 NaN
# 739            ...                                    NaN                 NaN
# 740            ...                                    NaN                 NaN
# 741            ...                                    NaN                 NaN
# 742            ...                                    NaN                 NaN
# 743            ...                                    NaN                 NaN
# 744            ...                                    NaN                 NaN
# 745            ...                                    NaN                 NaN
# 746            ...                                    NaN                 NaN
# 747            ...                                    NaN                 NaN
# 748            ...                                    NaN                 NaN
# 749            ...                                    NaN                 NaN
# 750            ...                                    NaN                 NaN
#
#      yellow stain  snno  Granular ilmenite  Granular Manganese  \
# 0             NaN   NaN                NaN                 NaN
# 1             NaN   NaN                NaN                 NaN
# 2             NaN   NaN                NaN                 NaN
# 3             NaN   NaN                NaN                 NaN
# 4             NaN   NaN                NaN                 NaN
# 5             NaN   NaN                NaN                 NaN
# 6             NaN   NaN                NaN                 NaN
# 7             NaN   NaN                NaN                 NaN
# 8             NaN   NaN                NaN                 NaN
# 9             NaN   NaN                NaN                 NaN
# 10            NaN   NaN                NaN                 NaN
# 11            NaN   NaN                NaN                 NaN
# 12            NaN   NaN                NaN                 NaN
# 13            NaN   NaN                NaN                 NaN
# 14            NaN   NaN                NaN                 NaN
# 15            NaN   NaN                NaN                 NaN
# 16            NaN   NaN                NaN                 NaN
# 17            NaN   NaN                NaN                 NaN
# 18            NaN   NaN                NaN                 NaN
# 19            NaN   NaN                NaN                 NaN
# 20            NaN   NaN                NaN                 NaN
# 21            NaN   NaN                NaN                 NaN
# 22            NaN   NaN                NaN                 NaN
# 23            NaN   NaN                NaN                 NaN
# 24            NaN   NaN                NaN                 NaN
# 25            NaN   NaN                NaN                 NaN
# 26            NaN   NaN                NaN                 NaN
# 27            NaN   NaN                NaN                 NaN
# 28            NaN   NaN                NaN                 NaN
# 29            NaN   NaN                NaN                 NaN
# ..            ...   ...                ...                 ...
# 721           NaN   NaN                NaN                 NaN
# 722           NaN   NaN                NaN                 NaN
# 723           NaN   NaN                NaN                 NaN
# 724           NaN   NaN                NaN                 NaN
# 725           NaN   NaN                NaN                 NaN
# 726           NaN   NaN                NaN                 NaN
# 727           NaN   NaN                NaN                 NaN
# 728           NaN   NaN                NaN                 NaN
# 729           NaN   NaN                NaN                 NaN
# 730           NaN   NaN                NaN                 NaN
# 731           NaN   NaN                NaN                 NaN
# 732           NaN   NaN                NaN                 NaN
# 733           NaN   NaN                NaN                 NaN
# 734           NaN   NaN                NaN                 NaN
# 735           NaN   NaN                NaN                 NaN
# 736           NaN   NaN                NaN                 NaN
# 737           NaN   NaN                NaN                 NaN
# 738           NaN   NaN                NaN                 NaN
# 739           NaN   NaN                NaN                 NaN
# 740           NaN   NaN                NaN                 NaN
# 741           NaN   NaN                NaN                 NaN
# 742           NaN   NaN                NaN                 NaN
# 743           NaN   NaN                NaN                 NaN
# 744           NaN   NaN                NaN                 NaN
# 745           NaN   NaN                NaN                 NaN
# 746           NaN   NaN                NaN                 NaN
# 747           NaN   NaN                NaN                 NaN
# 748           NaN   NaN                NaN                 NaN
# 749           NaN   NaN                NaN                 NaN
# 750           NaN   NaN                NaN                 NaN
#
#      Ilmenite (325 mesh best)  Ferric oxide  Nickel carbonate  \
# 0                         NaN           NaN               NaN
# 1                         NaN           NaN               NaN
# 2                         NaN           NaN               NaN
# 3                         NaN           NaN               NaN
# 4                         NaN           NaN               NaN
# 5                         NaN           NaN               NaN
# 6                         NaN           NaN               NaN
# 7                         NaN           NaN               NaN
# 8                         NaN           NaN               NaN
# 9                         NaN           NaN               NaN
# 10                        NaN           NaN               NaN
# 11                        NaN           NaN               NaN
# 12                        NaN           NaN               NaN
# 13                        NaN           NaN               NaN
# 14                        NaN           NaN               NaN
# 15                        NaN           NaN               NaN
# 16                        NaN           NaN               NaN
# 17                        NaN           NaN               NaN
# 18                        NaN           NaN               NaN
# 19                        NaN           NaN               NaN
# 20                        NaN           NaN               NaN
# 21                        NaN           NaN               NaN
# 22                        NaN           NaN               NaN
# 23                        NaN           NaN               NaN
# 24                        NaN           NaN               NaN
# 25                        NaN           NaN               NaN
# 26                        NaN           NaN               NaN
# 27                        NaN           NaN               NaN
# 28                        NaN           NaN               NaN
# 29                        NaN           NaN               NaN
# ..                        ...           ...               ...
# 721                       NaN           NaN               NaN
# 722                       NaN           NaN               NaN
# 723                       NaN           NaN               NaN
# 724                       NaN           NaN               NaN
# 725                       NaN           NaN               NaN
# 726                       NaN           NaN               NaN
# 727                       NaN           NaN               NaN
# 728                       NaN           NaN               NaN
# 729                       NaN           NaN               NaN
# 730                       NaN           NaN               NaN
# 731                       NaN           NaN               NaN
# 732                       NaN           NaN               NaN
# 733                       NaN           NaN               NaN
# 734                       NaN           NaN               NaN
# 735                       NaN           NaN               NaN
# 736                       NaN           NaN               NaN
# 737                       NaN           NaN               NaN
# 738                       NaN           NaN               NaN
# 739                       NaN           NaN               NaN
# 740                       NaN           NaN               NaN
# 741                       NaN           NaN               NaN
# 742                       NaN           NaN               NaN
# 743                       NaN           NaN               NaN
# 744                       NaN           NaN               NaN
# 745                       NaN           NaN               NaN
# 746                       NaN           NaN               NaN
# 747                       NaN           NaN               NaN
# 748                       NaN           NaN               NaN
# 749                       NaN           NaN               NaN
# 750                       NaN           NaN               NaN
#
#      Red iron oxide (Spanish)
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# ..                        ...
# 721                       NaN
# 722                       NaN
# 723                       NaN
# 724                       NaN
# 725                       NaN
# 726                       NaN
# 727                       NaN
# 728                       NaN
# 729                       NaN
# 730                       NaN
# 731                       NaN
# 732                       NaN
# 733                       NaN
# 734                       NaN
# 735                       NaN
# 736                       NaN
# 737                       NaN
# 738                       NaN
# 739                       NaN
# 740                       NaN
# 741                       NaN
# 742                       NaN
# 743                       NaN
# 744                       NaN
# 745                       NaN
# 746                       NaN
# 747                       NaN
# 748                       NaN
# 749                       NaN
# 750                       NaN
#
# [751 rows x 258 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
len(df)
# Out:
# 751

# %%
df['Color'][1]
# Out:
# nan
